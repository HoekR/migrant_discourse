# %% [markdown]
# ## Overlap of Political Organisations and Authors of Academic Research
#
# We look at the overlap between members of various organisations and the authors of the studies in REMP, IM and IMR:
#
# - REMP Board
# - ICEM directors and deputy directors
# - Dutch Government

# %%
import pandas as pd

records_file = '../data/main-review-article-records.csv'

# load the csv data into a data frame
pub_df = pd.read_csv(records_file)

# %%
from scripts.data_wrangling import map_dataset

pub_df['dataset'] = pub_df.apply(lambda x: map_dataset(x['publisher'], x['article_type']), axis=1)
pub_df.dataset.value_counts()
# Out:
# IMR_review      1842
# IMR_research    1539
# REMP_IM          903
# Name: dataset, dtype: int64

# %% [markdown]
# ## Clustering Author Names
#
# We want to see which authors published in both journals, and how often. This requires a number of transformations:
#
# 1. splitting records of multi-author papers into a record per author
# 2. normalising author names such that variant spellings are mapped to a single version.
#
# The latter step is always a risky operation, because using only the surface form of a name can results in two persons with similar names being considered as a single person. Given that this dataset narrowly focuses in only authors of articles in the two journals, we assume the chance that two authors have the same surname and initials is low.
#
#
# #### Splitting multi-author records

# %%
# Code adapted from https://stackoverflow.com/questions/50731229/split-cell-into-multiple-rows-in-pandas-dataframe

import numpy as np
from itertools import chain

# return list from series of comma-separated strings
def chainer(s):
    return list(chain.from_iterable(s.fillna('').str.split(' && ')))

# calculate lengths of splits
lens = pub_df['article_author'].fillna('').str.split(' && ').map(len)

# create new dataframe, repeating or chaining as appropriate
split_pub_df = pd.DataFrame({
    'journal': np.repeat(pub_df['journal'], lens),
    'issue_pub_year': np.repeat(pub_df['issue_pub_year'], lens),
    'publisher': np.repeat(pub_df['publisher'], lens),
    'dataset': np.repeat(pub_df['dataset'], lens),
    'article_author': chainer(pub_df['article_author']),
    'article_author_index_name': chainer(pub_df['article_author_index_name']),
    'article_author_affiliation': chainer(pub_df['article_author_affiliation'])
})

split_pub_df = split_pub_df.reset_index(drop=True)

# %% [markdown]
# #### Normalising author names
#
# There is a lot of variation in how author names are represented. Sometimes with full first and middle names, sometime with only the first name or only initials, or the first name in full but the middle names as initials.
#
# We start from the author format where the surname is followed by the first and middle names (field `article_author_index_name`). We apply the following normalisation and mapping steps:
#
# 1. transform the `article_author_index_name` to title casing (meaning each initial character of a name part is uppercase and the rest is lowercase),
# 2. remove everything after the first letter that follows the surname,
# 3. transform all uses of `ij` to `y` as this Dutch and German names containing `ij` are sometimes spelled with `y`, e.g. `Gunther Beijer` vs. `Gunther Beyer`.

# %%
from scripts.data_wrangling import parse_surname, parse_surname_initial, acronym

# Make sure title case is used consistently in the author index name column
split_pub_df['article_author_index_name'] = split_pub_df['article_author_index_name'].str.title()
# add a column with surname and first name initial extracted from the author index name
split_pub_df['author_surname_initial'] = split_pub_df.article_author_index_name.apply(parse_surname_initial)
# add a column with surname only
split_pub_df['author_surname'] = split_pub_df.article_author_index_name.apply(parse_surname)
# add a column with the decade in which the issue was published that contains an article
split_pub_df['issue_pub_decade'] = split_pub_df.issue_pub_year.apply(lambda x: int(x/10)*10)
# map journal names to their acronyms
split_pub_df.journal = split_pub_df.journal.apply(acronym)

# remove articles with no authors
split_pub_df =  split_pub_df[split_pub_df.article_author != '']

# %% [markdown]
# ## Parsing Organisational Membership Records
#
# We consider the REMP and ICEM as semi-political organisations. Some members of the Dutch government are closely collaborating with REMP and ICEM.

# %%
from scripts.network_analysis import retrieve_spreadsheet_records

entity_records = retrieve_spreadsheet_records(record_type='categories')
print('Number of records:' , len(entity_records))
# Out:
# Number of records: 74

# %%
import json

for record in entity_records:
    print(json.dumps(record, indent=4))
    #print(record['Organisation'], record['Prs_surname'])
# Out:
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1983",
#     "prs_id": "1",
#     "prs_surname": "Beijer",
#     "prs_infix": "",
#     "prs_initials": "G.",
#     "prs_function": "demographer, The Hague",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "NL",
#     "prs_role1": "founder",
#     "prs_role2": "member_MC",
#     "prs_role3": "secretary-editor",
#     "remarks": "director-editor (1969)"
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "2",
#     "prs_surname": "Groenman",
#     "prs_infix": "",
#     "prs_initials": "Sj.",
#     "prs_function": "sociologist, Leiden",
#     "prs_category": "academic",
#     "is_academic": "1947",
#     "is_public_administration": "1943-1950",
#     "prs_country": "NL",
#     "prs_role1": "founder",
#     "prs_role2": "member_MC",
#     "prs_role3": "vice-chair_BoD",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "3",
#     "prs_surname": "Zeegers",
#     "prs_infix": "",
#     "prs_initials": "G.H.L.",
#     "prs_function": "economist, sociologist, Nijmegen",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1941-1950",
#     "prs_country": "NL",
#     "prs_role1": "founder",
#     "prs_role2": "member_MC",
#     "prs_role3": "member_BoD",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "4",
#     "prs_surname": "Hofstee",
#     "prs_infix": "",
#     "prs_initials": "E.W.",
#     "prs_function": "sociologist, Wageningen",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "yes, advisor 5 ministeries",
#     "prs_country": "NL",
#     "prs_role1": "founder",
#     "prs_role2": "member_BoD",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "5",
#     "prs_surname": "Bouman",
#     "prs_infix": "",
#     "prs_initials": "P.J.",
#     "prs_function": "sociologist, Groningen",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "NL",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "chair_BoD (1954)",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "6",
#     "prs_surname": "Oldendorff",
#     "prs_infix": "",
#     "prs_initials": "A.",
#     "prs_function": "sociologist Tilburg",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1946-1947",
#     "prs_country": "NL",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1954",
#     "prs_id": "7",
#     "prs_surname": "Gelissen",
#     "prs_infix": "",
#     "prs_initials": "H.",
#     "prs_function": "chemist, politician",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1935-1937",
#     "prs_country": "NL",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "",
#     "prs_id": "8",
#     "prs_surname": "Schokking",
#     "prs_infix": "",
#     "prs_initials": "J.J.",
#     "prs_function": "lawyer + sociologist(?), Cologne",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "NL",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "9",
#     "prs_surname": "Sauvy",
#     "prs_infix": "",
#     "prs_initials": "A.",
#     "prs_function": "demographer,UN_comission for Population",
#     "prs_category": "academic",
#     "is_academic": "1945",
#     "is_public_administration": "1939",
#     "prs_country": "FR",
#     "prs_role1": "chair_BoD",
#     "prs_role2": "chair_MC",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "10",
#     "prs_surname": "Gottmann",
#     "prs_infix": "",
#     "prs_initials": "J.",
#     "prs_function": "geographer, Paris, Princeton",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1945",
#     "prs_country": "FR",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "11",
#     "prs_surname": "Lacroix",
#     "prs_infix": "",
#     "prs_initials": "M.",
#     "prs_function": "UN population section, New York",
#     "prs_category": "unknown",
#     "is_academic": "",
#     "is_public_administration": "yes, UN",
#     "prs_country": "FR",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": "source, arch beyer IISG, inv.nr. 31, notulen 11-2-1952"
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1957",
#     "prs_id": "12",
#     "prs_surname": "Jacobson",
#     "prs_infix": "",
#     "prs_initials": "P.",
#     "prs_function": "lawyer, linguist, DDG_ICEM, Geneva",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1952-1957",
#     "prs_country": "FR",
#     "prs_role1": "member_BoD",
#     "prs_role2": "Dep_dir_ICEM(?)",
#     "prs_role3": "",
#     "remarks": "dies 1957"
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "13",
#     "prs_surname": "Winkler",
#     "prs_infix": "",
#     "prs_initials": "W.",
#     "prs_function": "(Governmental) Statistician, Vienna",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1920-1955",
#     "prs_country": "AT",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "",
#     "prs_id": "14",
#     "prs_surname": "Janne",
#     "prs_infix": "",
#     "prs_initials": "H.",
#     "prs_function": "classicist, sociologist, Brussels, Brugge, politician",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1932-1965",
#     "prs_country": "BE",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "15",
#     "prs_surname": "Mertens de Wilmars",
#     "prs_infix": "",
#     "prs_initials": "J.",
#     "prs_function": "lawyer, political scienctist Louvain, politician",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "yes",
#     "prs_country": "BE",
#     "prs_role1": "member_BoD",
#     "prs_role2": "member_MC",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "16",
#     "prs_surname": "Baade",
#     "prs_infix": "",
#     "prs_initials": "F.",
#     "prs_function": "Economist, politician, Kiel",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1922-1935, 1949-1965",
#     "prs_country": "DE",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1955",
#     "prs_id": "17",
#     "prs_surname": "Mackenroth",
#     "prs_infix": "",
#     "prs_initials": "G.",
#     "prs_function": "lawyer, economist, psychologist",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1954-1955",
#     "prs_country": "DE",
#     "prs_role1": "member_BoD",
#     "prs_role2": "member_MC",
#     "prs_role3": "",
#     "remarks": "dies 1955"
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "18",
#     "prs_surname": "Ritschl",
#     "prs_infix": "",
#     "prs_initials": "H.",
#     "prs_function": "economist, Hamburg",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "yes, advisor Finanz ministerium 1950-1975",
#     "prs_country": "DE",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "19",
#     "prs_surname": "Hoffmann",
#     "prs_infix": "",
#     "prs_initials": "W.",
#     "prs_function": "economist Kiel, Munster",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "yes, advisor Wirtschaftsministerium 1948-1969",
#     "prs_country": "DE",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "20",
#     "prs_surname": "Neundorffer",
#     "prs_infix": "",
#     "prs_initials": "L.",
#     "prs_function": "sociologist (sociographie), Frankfurt a.M.",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "yes, 1933-1939; advisor Social policy 1955-1965",
#     "prs_country": "DE",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "",
#     "prs_id": "21",
#     "prs_surname": "Gadolin",
#     "prs_infix": "de",
#     "prs_initials": "A.",
#     "prs_function": "economist",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "FI",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1954",
#     "prs_id": "22",
#     "prs_surname": "Vito",
#     "prs_infix": "",
#     "prs_initials": "F.",
#     "prs_function": "economist, Milano",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "IT",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1954",
#     "prs_id": "23",
#     "prs_surname": "Livi",
#     "prs_infix": "",
#     "prs_initials": "L.",
#     "prs_function": "statistician, Florence",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "IT",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "24",
#     "prs_surname": "Parenti",
#     "prs_infix": "",
#     "prs_initials": "G.",
#     "prs_function": "statistician , Florence (OECD, ILO)",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "government consultant",
#     "prs_country": "IT",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "25",
#     "prs_surname": "Vergottini",
#     "prs_infix": "",
#     "prs_initials": "M.",
#     "prs_function": "statistician, mathematician, demographer, Catania/Rome",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "IT",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "",
#     "prs_id": "26",
#     "prs_surname": "Vampa",
#     "prs_infix": "",
#     "prs_initials": "D",
#     "prs_function": "Paris",
#     "prs_category": "unknown",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "IT",
#     "prs_role1": "member_BoD",
#     "prs_role2": "member_MC",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "27",
#     "prs_surname": "Hyrenius",
#     "prs_infix": "",
#     "prs_initials": "H.",
#     "prs_function": "demographer, statistician, Gothenburg (UN population division)",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "SE",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "28",
#     "prs_surname": "Salin",
#     "prs_infix": "",
#     "prs_initials": "E.W.",
#     "prs_function": "economist, historian, Basel",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "CH",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1954",
#     "prs_id": "29",
#     "prs_surname": "Rappard",
#     "prs_infix": "",
#     "prs_initials": "W.E.",
#     "prs_function": "economist, diplomat Geneva",
#     "prs_category": "diplomat",
#     "is_academic": "yes",
#     "is_public_administration": "yes",
#     "prs_country": "CH",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1969",
#     "prs_id": "30",
#     "prs_surname": "Nixon",
#     "prs_infix": "",
#     "prs_initials": "J.W.",
#     "prs_function": "statistician International Labour Office Geneva",
#     "prs_category": "unknown",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "CH",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "1957",
#     "prs_id": "31",
#     "prs_surname": "Isaac",
#     "prs_infix": "",
#     "prs_initials": "J.",
#     "prs_function": "National Institute of Economic and Social Research, London",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "UK",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": "dies 1957"
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "",
#     "prs_id": "32",
#     "prs_surname": "Marshall",
#     "prs_infix": "",
#     "prs_initials": "M.H.",
#     "prs_function": "Ottawa",
#     "prs_category": "unknown",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "CA",
#     "prs_role1": "Correspondent",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "",
#     "prs_id": "33",
#     "prs_surname": "Oudenhove",
#     "prs_infix": "van",
#     "prs_initials": "C.M.",
#     "prs_function": "Stellenbosch",
#     "prs_category": "unknown",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "ZA",
#     "prs_role1": "Correspondent",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "",
#     "prs_id": "34",
#     "prs_surname": "Kulischer",
#     "prs_infix": "",
#     "prs_initials": "E.",
#     "prs_function": "Washington",
#     "prs_category": "unknown",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "",
#     "prs_role1": "Correspondent",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1952",
#     "last_known_date": "",
#     "prs_id": "35",
#     "prs_surname": "Brink",
#     "prs_infix": "van den",
#     "prs_initials": "T.",
#     "prs_function": "statistician CBS",
#     "prs_category": "academic",
#     "is_academic": "",
#     "is_public_administration": "yes",
#     "prs_country": "NL",
#     "prs_role1": "member _MC",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1954",
#     "last_known_date": "1969",
#     "prs_id": "36",
#     "prs_surname": "Clark",
#     "prs_infix": "",
#     "prs_initials": "C.",
#     "prs_function": "econometrist, director Agricultural, Economic Research Institute Oxford",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "UK /AU",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1954",
#     "last_known_date": "1969",
#     "prs_id": "37",
#     "prs_surname": "Hofsten",
#     "prs_infix": "von",
#     "prs_initials": "E.A.",
#     "prs_function": "statistician, demographer",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "yes",
#     "prs_country": "SE",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1954",
#     "last_known_date": "1969",
#     "prs_id": "38",
#     "prs_surname": "Backer",
#     "prs_infix": "",
#     "prs_initials": "J.",
#     "prs_function": "statistician, chief demographic service, Statistick Sentralbyro",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "yes",
#     "prs_country": "NO",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1954",
#     "last_known_date": "1954",
#     "prs_id": "39",
#     "prs_surname": "Grot",
#     "prs_infix": "",
#     "prs_initials": "J.",
#     "prs_function": "Europese Economische Commissie UN, Geneva",
#     "prs_category": "unknown",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "unknown",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1954",
#     "last_known_date": "1969",
#     "prs_id": "40",
#     "prs_surname": "Goudswaard",
#     "prs_infix": "",
#     "prs_initials": "G.",
#     "prs_function": "statistician, director International Bureau of statistics",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "yes",
#     "prs_country": "NL",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1954",
#     "last_known_date": "1969",
#     "prs_id": "41",
#     "prs_surname": "Oblath",
#     "prs_infix": "",
#     "prs_initials": "A.",
#     "prs_function": "ILO (Manpower/Migration-div., Geneva",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "yes",
#     "prs_country": "IT",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1961",
#     "last_known_date": "1969",
#     "prs_id": "42",
#     "prs_surname": "Fougstedt",
#     "prs_infix": "",
#     "prs_initials": "G.",
#     "prs_function": "statistician, demographer, Fins Centraal Bureau Statistiek",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1935-1958",
#     "prs_country": "FI",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1961",
#     "last_known_date": "1969",
#     "prs_id": "43",
#     "prs_surname": "Thomas",
#     "prs_infix": "",
#     "prs_initials": "B.",
#     "prs_function": "unknown, Cardiff ",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "UK /AU",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1961",
#     "last_known_date": "1969",
#     "prs_id": "44",
#     "prs_surname": "Edding",
#     "prs_infix": "",
#     "prs_initials": "F.",
#     "prs_function": "economist, Kiel",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1935-1943",
#     "prs_country": "DE",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1961",
#     "last_known_date": "1969",
#     "prs_id": "45",
#     "prs_surname": "Kant",
#     "prs_infix": "",
#     "prs_initials": "E.",
#     "prs_function": "geographer, economist University of Lund, Sweden",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "EE",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1961",
#     "last_known_date": "1969",
#     "prs_id": "46",
#     "prs_surname": "Weinberg",
#     "prs_infix": "",
#     "prs_initials": "A.A.",
#     "prs_function": "Psychiatrist Jerusalem, Israel",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "IL",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1961",
#     "last_known_date": "1969",
#     "prs_id": "47",
#     "prs_surname": "Roof",
#     "prs_infix": "",
#     "prs_initials": "M.",
#     "prs_function": "Library of Congres, Washington",
#     "prs_category": "unknown",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "USA",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1961",
#     "last_known_date": "1969",
#     "prs_id": "48",
#     "prs_surname": "Bastos de Avila",
#     "prs_infix": "",
#     "prs_initials": "F.",
#     "prs_function": "priest, Rio de Janeira",
#     "prs_category": "academic",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "BR",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1969",
#     "last_known_date": "1969",
#     "prs_id": "49",
#     "prs_surname": "Oudegeest",
#     "prs_infix": "",
#     "prs_initials": "J.J.",
#     "prs_function": "sociologist, demographer (?), Den Haag",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "NL",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1969",
#     "last_known_date": "1969",
#     "prs_id": "50",
#     "prs_surname": "Appleyard",
#     "prs_infix": "",
#     "prs_initials": "R.T.",
#     "prs_function": "economist, Perth",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "",
#     "prs_country": "AU",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "REMP",
#     "period_start": "1969",
#     "last_known_date": "1969",
#     "prs_id": "51",
#     "prs_surname": "Borrie",
#     "prs_infix": "",
#     "prs_initials": "W.",
#     "prs_function": "economist, demographer Canberra",
#     "prs_category": "academic",
#     "is_academic": "yes",
#     "is_public_administration": "1970-1981",
#     "prs_country": "AU",
#     "prs_role1": "member_BoD",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "Dutch Government",
#     "period_start": "1945",
#     "last_known_date": "1969",
#     "prs_id": "52",
#     "prs_surname": "Haveman",
#     "prs_infix": "",
#     "prs_initials": "B.W.",
#     "prs_function": "chemist, law, RCE",
#     "prs_category": "",
#     "is_academic": "no",
#     "is_public_administration": "yes",
#     "prs_country": "NL",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "Dutch Government",
#     "period_start": "1952",
#     "last_known_date": "1967",
#     "prs_id": "53",
#     "prs_surname": "Hofstede",
#     "prs_infix": "",
#     "prs_initials": "B.P.",
#     "prs_function": "sociologist, RCE",
#     "prs_category": "",
#     "is_academic": "1964",
#     "is_public_administration": "yes",
#     "prs_country": "NL",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "Dutch Government",
#     "period_start": "1946",
#     "last_known_date": "1972",
#     "prs_id": "54",
#     "prs_surname": "Verwey-Jonker",
#     "prs_infix": "",
#     "prs_initials": "H.",
#     "prs_function": "sociologist",
#     "prs_category": "academic",
#     "is_academic": "1973",
#     "is_public_administration": "yes",
#     "prs_country": "NL",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "Dutch Government",
#     "period_start": "1956",
#     "last_known_date": "1971",
#     "prs_id": "55",
#     "prs_surname": "Klompe",
#     "prs_infix": "",
#     "prs_initials": "M.",
#     "prs_function": "chemist",
#     "prs_category": "",
#     "is_academic": "no",
#     "is_public_administration": "yes",
#     "prs_country": "NL",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": "1956-1963 Minister MW; 1966-1971 min CRM"
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1952",
#     "last_known_date": "1954",
#     "prs_id": "56",
#     "prs_surname": "Gibson",
#     "prs_infix": "",
#     "prs_initials": "Hugh S.",
#     "prs_function": "director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "USA",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1955",
#     "last_known_date": "1958",
#     "prs_id": "57",
#     "prs_surname": "Tittman Jr.",
#     "prs_infix": "",
#     "prs_initials": "Harold H.",
#     "prs_function": "director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "USA",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1958",
#     "last_known_date": "1961",
#     "prs_id": "58",
#     "prs_surname": "Daley",
#     "prs_infix": "",
#     "prs_initials": "Marcus",
#     "prs_function": "director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "USA",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1961",
#     "last_known_date": "1969",
#     "prs_id": "52",
#     "prs_surname": "Haveman",
#     "prs_infix": "",
#     "prs_initials": "Bastiaan W.",
#     "prs_function": "director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "NL",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1969",
#     "last_known_date": "1979",
#     "prs_id": "59",
#     "prs_surname": "Thomas",
#     "prs_infix": "",
#     "prs_initials": "John",
#     "prs_function": "director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "USA",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1979",
#     "last_known_date": "1988",
#     "prs_id": "60",
#     "prs_surname": "Carlin",
#     "prs_infix": "",
#     "prs_initials": "James L.",
#     "prs_function": "director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "USA",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1988",
#     "last_known_date": "1998",
#     "prs_id": "61",
#     "prs_surname": "Purcell jr.",
#     "prs_infix": "",
#     "prs_initials": "James",
#     "prs_function": "director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "USA",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1998",
#     "last_known_date": "2008",
#     "prs_id": "62",
#     "prs_surname": "McKinley",
#     "prs_infix": "",
#     "prs_initials": "Brunson",
#     "prs_function": "director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "USA",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "2008",
#     "last_known_date": "2018",
#     "prs_id": "63",
#     "prs_surname": "Swing",
#     "prs_infix": "",
#     "prs_initials": "William Lacey",
#     "prs_function": "director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "USA",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "2018",
#     "last_known_date": "",
#     "prs_id": "64",
#     "prs_surname": "Vitorino",
#     "prs_infix": "",
#     "prs_initials": "Antonio",
#     "prs_function": "director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "PT",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1952",
#     "last_known_date": "1957",
#     "prs_id": "12",
#     "prs_surname": "Jacobson",
#     "prs_infix": "",
#     "prs_initials": "P.",
#     "prs_function": "deputy director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "FR",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1957",
#     "last_known_date": "1961",
#     "prs_id": "65",
#     "prs_surname": "Epinat",
#     "prs_infix": "",
#     "prs_initials": "B.G.",
#     "prs_function": "deputy director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "FR",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1961",
#     "last_known_date": "1964",
#     "prs_id": "66",
#     "prs_surname": "MacFadden",
#     "prs_infix": "",
#     "prs_initials": "J.B.",
#     "prs_function": "deputy director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "USA",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1964",
#     "last_known_date": "1970",
#     "prs_id": "67",
#     "prs_surname": "Besterman",
#     "prs_infix": "",
#     "prs_initials": "W.M.",
#     "prs_function": "deputy director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "USA",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1970",
#     "last_known_date": "1988",
#     "prs_id": "68",
#     "prs_surname": "Maselli",
#     "prs_infix": "",
#     "prs_initials": "G.",
#     "prs_function": "deputy director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "IT",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1989",
#     "last_known_date": "1993",
#     "prs_id": "69",
#     "prs_surname": "Charry-Samper",
#     "prs_infix": "",
#     "prs_initials": "H.",
#     "prs_function": "deputy director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "CO",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1994",
#     "last_known_date": "1999",
#     "prs_id": "70",
#     "prs_surname": "Escaler",
#     "prs_infix": "",
#     "prs_initials": "N.L. (Narcisa)",
#     "prs_function": "deputy director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "PH",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "1999",
#     "last_known_date": "2009",
#     "prs_id": "71",
#     "prs_surname": "Ndioro",
#     "prs_infix": "",
#     "prs_initials": "N. (Ndiaye)",
#     "prs_function": "deputy director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "SN",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }
# {
#     "organisation": "ICEM",
#     "period_start": "2009",
#     "last_known_date": "",
#     "prs_id": "72",
#     "prs_surname": "Thompson",
#     "prs_infix": "",
#     "prs_initials": "L. (Laura)",
#     "prs_function": "deputy director general",
#     "prs_category": "",
#     "is_academic": "",
#     "is_public_administration": "",
#     "prs_country": "CR",
#     "prs_role1": "",
#     "prs_role2": "",
#     "prs_role3": "",
#     "remarks": ""
# }

# %%
from scripts.data_wrangling import parse_author_index_name

board_df = pd.DataFrame(entity_records)
b_cols = {c:c.lower() for c in board_df.columns}
board_df.rename(columns=b_cols, inplace=True)
board_df['article_author_index_name'] = board_df.apply(parse_author_index_name, axis=1)
board_df['author_surname_initial'] = board_df.article_author_index_name.apply(parse_surname_initial)
board_df
# Out:
#    organisation period_start last_known_date prs_id    prs_surname prs_infix  \
# 0          REMP         1952            1983      1         Beijer
# 1          REMP         1952            1969      2       Groenman
# 2          REMP         1952            1969      3        Zeegers
# 3          REMP         1952            1969      4        Hofstee
# 4          REMP         1952            1969      5         Bouman
# ..          ...          ...             ...    ...            ...       ...
# 69         ICEM         1970            1988     68        Maselli
# 70         ICEM         1989            1993     69  Charry-Samper
# 71         ICEM         1994            1999     70        Escaler
# 72         ICEM         1999            2009     71         Ndioro
# 73         ICEM         2009                     72       Thompson
#
#       prs_initials                      prs_function prs_category is_academic  \
# 0               G.            demographer, The Hague     academic         yes
# 1              Sj.               sociologist, Leiden     academic        1947
# 2           G.H.L.  economist, sociologist, Nijmegen     academic         yes
# 3             E.W.           sociologist, Wageningen     academic         yes
# 4             P.J.            sociologist, Groningen     academic         yes
# ..             ...                               ...          ...         ...
# 69              G.           deputy director general
# 70              H.           deputy director general
# 71  N.L. (Narcisa)           deputy director general
# 72     N. (Ndiaye)           deputy director general
# 73      L. (Laura)           deputy director general
#
#       is_public_administration prs_country   prs_role1   prs_role2  \
# 0                                       NL     founder   member_MC
# 1                    1943-1950          NL     founder   member_MC
# 2                    1941-1950          NL     founder   member_MC
# 3   yes, advisor 5 ministeries          NL     founder  member_BoD
# 4                                       NL  member_BoD
# ..                         ...         ...         ...         ...
# 69                                      IT
# 70                                      CO
# 71                                      PH
# 72                                      SN
# 73                                      CR
#
#            prs_role3                 remarks article_author_index_name  \
# 0   secretary-editor  director-editor (1969)                Beijer, G.
# 1     vice-chair_BoD                                     Groenman, Sj.
# 2         member_BoD                                   Zeegers, G.H.L.
# 3                                                        Hofstee, E.W.
# 4   chair_BoD (1954)                                      Bouman, P.J.
# ..               ...                     ...                       ...
# 69                                                         Maselli, G.
# 70                                                   Charry-Samper, H.
# 71                                             Escaler, N.L. (Narcisa)
# 72                                                 Ndioro, N. (Ndiaye)
# 73                                                Thompson, L. (Laura)
#
#    author_surname_initial
# 0                Beyer, G
# 1             Groenman, S
# 2              Zeegers, G
# 3              Hofstee, E
# 4               Bouman, P
# ..                    ...
# 69             Maselli, G
# 70       Charry-Samper, H
# 71             Escaler, N
# 72              Ndioro, N
# 73            Thompson, L
#
# [74 rows x 18 columns]

# %%
from scripts.data_wrangling import yr2cat
board_df['period'] = board_df.apply(lambda x: yr2cat(x), axis=1)

# %%
decades = {1950:(1950, 1960),
 1960:(1960, 1970),
 1970:(1970, 1980),
 1980:(1980, 1990),
 1990:(1990, 2000),
 2000:(2000, 2010)
          }

def cutdecade(x, decade):
    result = False
    if x.right < decade[0]:
        return False
    if x.left > decade[1]:
        return False
    if x.left > decade[0] or x.right >= decade[0]:
        return True



for key in decades:
    decade = decades[key]
    board_df[key] = board_df.period.apply(lambda x: cutdecade(x, decade))

# %%
board_df[board_df.prs_surname == 'Thomas'].sort_values(by='prs_surname')
#board_df.prs_surname.value_counts()
# Out:
#    organisation period_start last_known_date prs_id prs_surname prs_infix  \
# 42         REMP         1961            1969     43      Thomas
# 59         ICEM         1969            1979     59      Thomas
#
#    prs_initials       prs_function prs_category is_academic  ... remarks  \
# 42           B.  unknown, Cardiff                            ...
# 59         John   director general                           ...
#
#    article_author_index_name author_surname_initial        period   1950  \
# 42                Thomas, B.              Thomas, B  [1961, 1969]  False
# 59              Thomas, John              Thomas, J  [1969, 1979]  False
#
#     1960   1970   1980   1990   2000
# 42  True  False  False  False  False
# 59  True   True  False  False  False
#
# [2 rows x 25 columns]

# %%
from scripts.data_wrangling import map_bool

decade_cols = [1950, 1960, 1970, 1980, 1990]
org_cols = ['author_surname_initial', 'organisation']
display_cols =  org_cols + decade_cols


temp_board_df = board_df[org_cols].merge(board_df[decade_cols].astype(int), left_index=True, right_index=True)
temp_board_df = temp_board_df.rename(columns={'dataset': 'cat'})
temp_board_df['in_board'] = 1
temp_board_df
# Out:
#    author_surname_initial organisation  1950  1960  1970  1980  1990  in_board
# 0                Beyer, G         REMP     1     1     1     1     0         1
# 1             Groenman, S         REMP     1     1     0     0     0         1
# 2              Zeegers, G         REMP     1     1     0     0     0         1
# 3              Hofstee, E         REMP     1     1     0     0     0         1
# 4               Bouman, P         REMP     1     1     0     0     0         1
# ..                    ...          ...   ...   ...   ...   ...   ...       ...
# 69             Maselli, G         ICEM     0     1     1     1     0         1
# 70       Charry-Samper, H         ICEM     0     0     0     1     1         1
# 71             Escaler, N         ICEM     0     0     0     0     1         1
# 72              Ndioro, N         ICEM     0     0     0     0     1         1
# 73            Thompson, L         ICEM     0     0     0     0     0         1
#
# [74 rows x 8 columns]

# %%
decade_pub_df = pd.get_dummies(split_pub_df.issue_pub_decade)

temp_pub_df = split_pub_df[['author_surname_initial', 'dataset']].merge(decade_pub_df, left_index=True, right_index=True)
temp_pub_df = temp_pub_df.rename(columns={'dataset': 'cat'})
temp_pub_df = temp_pub_df.groupby(['author_surname_initial', 'cat']).sum().reset_index()
temp_pub_df['in_pub'] = 1
temp_pub_df
# Out:
#      author_surname_initial           cat  1950  1960  1970  1980  1990  \
# 0                    A.H.R.  IMR_research     0     0     1     0     0
# 1                   Abad, R  IMR_research     0     0     0     2     0
# 2            Abadan-Unat, N  IMR_research     0     0     1     1     3
# 3            Abadan-Unat, N    IMR_review     0     0     0     1     0
# 4                 Abalos, D    IMR_review     0     0     1     0     0
# ...                     ...           ...   ...   ...   ...   ...   ...
# 2832             Zolberg, A    IMR_review     0     0     0     1     0
# 2833           Zubrzycki, J  IMR_research     0     0     2     1     0
# 2834           Zubrzycki, J       REMP_IM     3     5     0     1     0
# 2835              Zucchi, J    IMR_review     0     0     0     1     0
# 2836              Zucker, N    IMR_review     0     0     0     0     1
#
#       in_pub
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 2832       1
# 2833       1
# 2834       1
# 2835       1
# 2836       1
#
# [2837 rows x 8 columns]

# %%
#temp_pub_df.set_index('author_surname_initial')

temp_df = pd.concat([temp_board_df.rename(columns={'organisation': 'cat'}).set_index('author_surname_initial'), 
                     temp_pub_df.rename(columns={'dataset': 'cat'}).set_index('author_surname_initial')])

for name in temp_df.index:
    temp_df.loc[name,'in_pub'] = temp_df.loc[name,'in_pub'].max()
    temp_df.loc[name,'in_board'] = temp_df.loc[name,'in_board'].max()
temp_df = temp_df.reset_index()

# %%
from scripts.data_wrangling import highlight_decade

temp2_df = temp_df[(temp_df.in_board == 1) & (temp_df.in_pub == 1)].drop(['in_board', 'in_pub'], axis=1)
temp2_df.sort_values(by='author_surname_initial').style.apply(highlight_decade, axis=1)
# Out:
# <style  type="text/css" >
# #T_42dea90e_d361_11eb_b29e_8c859046a173row0_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row0_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row0_col4,#T_42dea90e_d361_11eb_b29e_8c859046a173row0_col5,#T_42dea90e_d361_11eb_b29e_8c859046a173row0_col6,#T_42dea90e_d361_11eb_b29e_8c859046a173row3_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row3_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row5_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row7_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row9_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row9_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row9_col4,#T_42dea90e_d361_11eb_b29e_8c859046a173row9_col5,#T_42dea90e_d361_11eb_b29e_8c859046a173row13_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row13_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row15_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row18_col5,#T_42dea90e_d361_11eb_b29e_8c859046a173row20_col6,#T_42dea90e_d361_11eb_b29e_8c859046a173row22_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row24_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row25_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row27_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row31_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row32_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row35_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row37_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row38_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row40_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row42_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row42_col4,#T_42dea90e_d361_11eb_b29e_8c859046a173row45_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row45_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row47_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row48_col6,#T_42dea90e_d361_11eb_b29e_8c859046a173row50_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row53_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row53_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row55_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row59_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row63_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row64_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row64_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row67_col2{
#             background-color:  #0000ff;
#         }#T_42dea90e_d361_11eb_b29e_8c859046a173row1_col5,#T_42dea90e_d361_11eb_b29e_8c859046a173row11_col5,#T_42dea90e_d361_11eb_b29e_8c859046a173row61_col6{
#             background-color:  #8888ff;
#         }#T_42dea90e_d361_11eb_b29e_8c859046a173row2_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row4_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row6_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row6_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row12_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row12_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row12_col4,#T_42dea90e_d361_11eb_b29e_8c859046a173row12_col5,#T_42dea90e_d361_11eb_b29e_8c859046a173row14_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row16_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row21_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row23_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row26_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row26_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row28_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row28_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row34_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row34_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row36_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row36_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row39_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row41_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row44_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row44_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row46_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row51_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row52_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row52_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row56_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row65_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row66_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row66_col3{
#             background-color:  #ff0000;
#         }#T_42dea90e_d361_11eb_b29e_8c859046a173row8_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row8_col4,#T_42dea90e_d361_11eb_b29e_8c859046a173row17_col4,#T_42dea90e_d361_11eb_b29e_8c859046a173row17_col5,#T_42dea90e_d361_11eb_b29e_8c859046a173row19_col5,#T_42dea90e_d361_11eb_b29e_8c859046a173row19_col6,#T_42dea90e_d361_11eb_b29e_8c859046a173row29_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row43_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row43_col4,#T_42dea90e_d361_11eb_b29e_8c859046a173row43_col5,#T_42dea90e_d361_11eb_b29e_8c859046a173row49_col5,#T_42dea90e_d361_11eb_b29e_8c859046a173row49_col6,#T_42dea90e_d361_11eb_b29e_8c859046a173row57_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row57_col4{
#             background-color:  #ff6666;
#         }#T_42dea90e_d361_11eb_b29e_8c859046a173row10_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row10_col4,#T_42dea90e_d361_11eb_b29e_8c859046a173row54_col4,#T_42dea90e_d361_11eb_b29e_8c859046a173row58_col5{
#             background-color:  #bbbbff;
#         }#T_42dea90e_d361_11eb_b29e_8c859046a173row30_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row30_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row33_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row33_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row62_col2,#T_42dea90e_d361_11eb_b29e_8c859046a173row62_col3,#T_42dea90e_d361_11eb_b29e_8c859046a173row62_col4{
#             background-color:  #ffbbbb;
#         }</style><table id="T_42dea90e_d361_11eb_b29e_8c859046a173" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >author_surname_initial</th>        <th class="col_heading level0 col1" >cat</th>        <th class="col_heading level0 col2" >1950</th>        <th class="col_heading level0 col3" >1960</th>        <th class="col_heading level0 col4" >1970</th>        <th class="col_heading level0 col5" >1980</th>        <th class="col_heading level0 col6" >1990</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42dea90e_d361_11eb_b29e_8c859046a173level0_row0" class="row_heading level0 row0" >166</th>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row0_col0" class="data row0 col0" >Appleyard, R</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row0_col1" class="data row0 col1" >REMP_IM</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row0_col2" class="data row0 col2" >2</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row0_col5" class="data row0 col5" >3</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row0_col6" class="data row0 col6" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_42dea90e_d361_11eb_b29e_8c859046a173level0_row1" class="row_heading level0 row1" >165</th>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row1_col0" class="data row1 col0" >Appleyard, R</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row1_col1" class="data row1 col1" >IMR_research</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row1_col5" class="data row1 col5" >1</td>
#                         <td id="T_42dea90e_d361_11eb_b29e_8c859046a173row1_col6" class="data row1 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_42dea90e_d361_11eb_b29e_8c8
