# %% [markdown]
# # Analysing Topical Shifts in Migration Publication via Title Words
#
# The titles of publications on migration management give us an overview of what the scientific community focused in their research over the decades.
#
# The dataset consists of authors, titles and publication year of articles published in the journal International Migration (IM) over the period 1961-2011.
#
# We use Content Analysis as a method to investigate topical shifts in the discourse around migration management. “Content analysis is an approach to the analysis of documents and texts (which may consist of words and/or images and may be printed or online, written or spoken) that seeks to quantify content in terms of predetermined categories and in a systematic and replicable manner.” (Bryman, 2016, p.283).
#
#
# ### References
#
# Bryman, A. (2016). Social research methods (Fifth edition.). Oxford ; New York: Oxford University Press.

# %% [markdown]
# ## Loading and inspecting the dataset
#
# We start by loading the dataset in Pandas, which allows us to do basic analysis of the metadata.

# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import re

# %%
# the name and location of the article records for the IM journal (in CSV format)
records_file = '../data/main-review-article-records.csv'

# load the csv data into a data frame
df = pd.read_csv(records_file)
# show the first and last records of the dataset to demonstrate what the records look like
df.head(5)
# Out:
#    Unnamed: 0                                      article_title article_doi  \
# 0           0  De gaande man : gronden van de emigratiebeslis...         NaN
# 1           2  Emigranten, niet-emigranten : kwantitatieve an...         NaN
# 2           5  Kenmerken van de Nederlandse emigrant : een an...         NaN
# 3           8  Emigranten overzee : resultaten van een eerste...         NaN
# 4           9  The importance of emigration for the solution ...         NaN
#
#    article_author article_author_index_name article_author_affiliation  \
# 0  Hofstede, B.P.            Hofstede, B.P.                        NaN
# 1    Frijda, N.H.              Frijda, N.H.                        NaN
# 2    Wentholt, R.              Wentholt, R.                        NaN
# 3    Frijda, N.H.              Frijda, N.H.                        NaN
# 4      Wander, H.                Wander, H.                        NaN
#
#   article_page_range article_pub_date  article_pub_year issue_section  \
# 0                NaN             1958              1958       article
# 1                NaN             1960              1960       article
# 2                NaN             1961              1961       article
# 3                NaN             1962              1962       article
# 4                NaN             1951              1951       article
#
#   issue_number issue_title issue_page_range issue_pub_date  issue_pub_year  \
# 0          NaN         NaN              NaN           1958            1958
# 1          NaN         NaN              NaN           1960            1960
# 2          NaN         NaN              NaN           1961            1961
# 3          NaN         NaN              NaN           1962            1962
# 4          NaN         NaN              NaN           1951            1951
#
#   volume                                            journal publisher  \
# 0      1                 Studies over Nederlandse emigratie      REMP
# 1      2                 Studies over Nederlandse emigratie      REMP
# 2      3                 Studies over Nederlandse emigratie      REMP
# 3      4                 Studies over Nederlandse emigratie      REMP
# 4      1  Publications of the research group for europea...      REMP
#
#   article_type
# 0         main
# 1         main
# 2         main
# 3         main
# 4         main

# %% [markdown]
# ### Basic summary statistics

# %% [markdown]
# A count of the values in the journal name column, reveals that the metadata of articles has some variation, but almost all use the canonical _International Migration_. In the early years, the journal was called _Migration_ but also _Migracion_ was used. Some contributed articles are written in Spanish or French.

# %%
df[['publisher', 'article_type']].value_counts().sort_index()
# Out:
# publisher        article_type
# REMP             main             143
# Sage Publishing  main            1584
#                  review          1916
# Wiley            main             747
#                  review            47
# dtype: int64

# %% [markdown]
# ## Data Selection
#
# Before performing a content analysis of the article titles, we want to make a selection of titles that is focused on the academic debate around migration, without any distracting non-topical titles that might obscure any topical shifts across the decades from 1950-2000.
#
# Given the analysis above, we use the following three sets of articles for analysis:
#
# 1. main articles from REMP and IM, plus the IM review articles,
# 2. main articles from IMR
# 3. review articles from IMR
#
# The reason to combine the main and review articles of IM is that the number of review articles is too low for independent content analysis.

# %%
def map_dataset(journal, article_type):
    if journal != 'International Migration Review' and article_type != 'supplementary':
        return 'REMP_IM'
    elif journal == 'International Migration Review' and article_type == 'main':
        return 'IMR_main'
    elif journal == 'International Migration Review' and article_type == 'review':
        return 'IMR_review'
    else:
        return None

df['dataset'] = df.apply(lambda x: map_dataset(x['journal'], x['article_type']), axis=1)
df.dataset.value_counts()
# Out:
# IMR_review    1916
# IMR_main      1584
# REMP_IM        937
# Name: dataset, dtype: int64

# %% [markdown]
# This leaves 1183 out of 1690 article titles for analysis.

# %% [markdown]
# ## Analysing the Article Titles
#
# To analyse the topics of discourse, we use the article titles. To do a content analysis, some data transformations are needed:
#
# - standardising the use of upper and lowercase characters,
# - removing common stopwords, as they convey nothing about the topics discussed
# - counting individual words and sequences of words as a quantitative signal for the attention to different topics.
#
# We look specifically at:
#
# - word unigram frequencies: how often individual words occur across titles
# - word bigram frequencies: how often combinations of two words occur across titles.
#
# To demonstrate the need for the transformations described above, we look at the first 20 titles.

# %%
# Get a list of all the titles
titles = list(df_selected.article_title)

# show the first 20 titles
titles[:20]
# Out:
# ['Community Services and Out-Migration',
#  "Europe's Migration Agreements with Migrant-Sending Countries in the Global South: A Critical Review",
#  'International Migration and Development in Asia: Exploring Knowledge Frameworks',
#  "Theoretical Considerations and Empirical Evidence on Brain Drain Grounding the Review of Albania's and Bulgaria's Experience 1",
#  'Causes, Challenges and Prospects of Brain Drain: The Case of Eritrea',
#  'A Desire to Return to the Country of Birth as a Function of Language Preference: An Empirical Study with Iranian Immigrants in the United States',
#  'Religious Status and Drug-use Behaviour among Former Soviet Union Immigrants',
#  '“Reconsidering the Study of International Migration: A Way Forward for Macrostructural Migration Research”',
#  'The New U.S.A. Immigration Law',
#  'Post-War Migration to Switzerland*',
#  'The Decline in Religious Participation of Migrants',
#  'The Repatriation of French Algerians 1962-1963',
#  'The Migration Problem And The Encyclical “Mater Et Magistra”: Historical Development Of The Moral Aspects Of Human Migration From 1500 A.D. To The Present Day',
#  'Argentina As An Immigration Country',
#  'How Migration Affects The Country Of Emigration',
#  'Sociological Methods For The Study Of Immigrant Adjustement',
#  'Best Practices to Reduce Migration Pressures',
#  'Averting Forced Migration in Countries in Transition',
#  'Towards a Coherent Policy of Co-Development',
#  'Best Practice Options: Yugoslavia']

# %% [markdown]
# #### Inconsistent Case
#
# The titles differ in their use of upper and lower case, so one step is to normalise all titles to be lower case.
#
# One consequence of this is that meaningful differences between a word with an initial uppercase that is part of a name (like _Migration_ in the organisation name _Internationl Committee for European Migration_) is merged with the regular noun _migration_. But in most cases this is not a problem, as they represent the same concept. Moreover, titles of journal article tend to use title casing of all words in the title, or at least all content-bearing words (i.e. non-stopwords). So it is difficult to make this distinction with algorithmic processing anyway.

# %%
# show the first 20 titles
[title.lower() for title in titles[:20]]
# Out:
# ['community services and out-migration',
#  "europe's migration agreements with migrant-sending countries in the global south: a critical review",
#  'international migration and development in asia: exploring knowledge frameworks',
#  "theoretical considerations and empirical evidence on brain drain grounding the review of albania's and bulgaria's experience 1",
#  'causes, challenges and prospects of brain drain: the case of eritrea',
#  'a desire to return to the country of birth as a function of language preference: an empirical study with iranian immigrants in the united states',
#  'religious status and drug-use behaviour among former soviet union immigrants',
#  '“reconsidering the study of international migration: a way forward for macrostructural migration research”',
#  'the new u.s.a. immigration law',
#  'post-war migration to switzerland*',
#  'the decline in religious participation of migrants',
#  'the repatriation of french algerians 1962-1963',
#  'the migration problem and the encyclical “mater et magistra”: historical development of the moral aspects of human migration from 1500 a.d. to the present day',
#  'argentina as an immigration country',
#  'how migration affects the country of emigration',
#  'sociological methods for the study of immigrant adjustement',
#  'best practices to reduce migration pressures',
#  'averting forced migration in countries in transition',
#  'towards a coherent policy of co-development',
#  'best practice options: yugoslavia']

# %% [markdown]
# For analysing in how many titles each word occurs, there are several other issues:
#
# - some titles have footnote symbols like '*' and '1', which are not part of the words they are attached to. For example: "theoretical considerations and empirical evidence on brain drain grounding the review of albania's and bulgaria's experience 1"
#     - **The normalisation step is to remove these symbols.**
# - some words contain contractions like "Europe's". We only want to count the content word, e.g. 'Europe'.
#     - **The normalisation step is to remove the 's part to retain only the content word.**
# - some titles contain acronyms with dots, like A.D., C.E.E. or U.S.A.
#     - **The normalisation steps is to remove the dots.**
# - We want to compare plain words without any attached punctuation, such that “mater et magistra” should become three words 'mater', 'et', 'magistra' without the opening and closing double quote characters
#     - **The normalisation step is to replace all such punctuation symbols by a whitespace, so that their removal doesn't contract two words on opposite so of the punctuation.**
#     - **The exception is hyphenated words, which should remain intact, e.g. 'co-development' should be treated as a single word.**

# %%
def remove_footnote_symbols(title):
    """Remove footnote symbols in the title like * and 1."""
    title = re.sub(r'([a-z]+)[12]', r'\1', title)
    if title.endswith('*'):
        return title[:-1]
    elif title.endswith(' 1'):
        return title[:-2]
    else:
        return title
    
    
def normalise_acronyms(title):
    """Remove dots in acronyms (A.D. -> AD , U.S.A. -> USA)"""
    match = re.search(r'\b((\w\.){2,})', title)
    if match:
        acronym = match.group(1)
        normalised_acronym = acronym.replace('.','')
        title = title.replace(acronym, normalised_acronym)
    return title
        

def resolve_apostrophes(title):
    """Remove 's from words."""
    title = title.replace("‘", "'")
    title = re.sub(r"(\w)'s\b", r'\1', title)
    return title


def remove_punctuation(title):
    """Remove all non-alpha-numeric characters except whitespace and hyphens"""
    title = re.sub(r'[^\w -]', ' ', title)
    return title


def collapse_multiple_whitespace(title):
    """Reduce multiple whitespace to a single whitespace, e.g. '  ' -> ' '. """
    title = re.sub(r' +', ' ', title)
    return title


def normalise_title(title):
    title = remove_footnote_symbols(title)
    title = normalise_acronyms(title)
    title = resolve_apostrophes(title)
    title = remove_punctuation(title)
    title = collapse_multiple_whitespace(title)
    return title.lower()

def demonstrate_normalisation():
    titles = list(df_selected.article_title)
    for title in titles:
        print('Original:', title)
        title = normalise_title(title)
        print('Normalised:', title)
        print()

demonstrate_normalisation()
# Out:
# Original: Community Services and Out-Migration
# Normalised: community services and out-migration
#
# Original: Europe's Migration Agreements with Migrant-Sending Countries in the Global South: A Critical Review
# Normalised: europe migration agreements with migrant-sending countries in the global south a critical review
#
# Original: International Migration and Development in Asia: Exploring Knowledge Frameworks
# Normalised: international migration and development in asia exploring knowledge frameworks
#
# Original: Theoretical Considerations and Empirical Evidence on Brain Drain Grounding the Review of Albania's and Bulgaria's Experience 1
# Normalised: theoretical considerations and empirical evidence on brain drain grounding the review of albania and bulgaria experience
#
# Original: Causes, Challenges and Prospects of Brain Drain: The Case of Eritrea
# Normalised: causes challenges and prospects of brain drain the case of eritrea
#
# Original: A Desire to Return to the Country of Birth as a Function of Language Preference: An Empirical Study with Iranian Immigrants in the United States
# Normalised: a desire to return to the country of birth as a function of language preference an empirical study with iranian immigrants in the united states
#
# Original: Religious Status and Drug-use Behaviour among Former Soviet Union Immigrants
# Normalised: religious status and drug-use behaviour among former soviet union immigrants
#
# Original: “Reconsidering the Study of International Migration: A Way Forward for Macrostructural Migration Research”
# Normalised:  reconsidering the study of international migration a way forward for macrostructural migration research
#
# Original: The New U.S.A. Immigration Law
# Normalised: the new usa immigration law
#
# Original: Post-War Migration to Switzerland*
# Normalised: post-war migration to switzerland
#
# Original: The Decline in Religious Participation of Migrants
# Normalised: the decline in religious participation of migrants
#
# Original: The Repatriation of French Algerians 1962-1963
# Normalised: the repatriation of french algerians 1962-1963
#
# Original: The Migration Problem And The Encyclical “Mater Et Magistra”: Historical Development Of The Moral Aspects Of Human Migration From 1500 A.D. To The Present Day
# Normalised: the migration problem and the encyclical mater et magistra historical development of the moral aspects of human migration from 1500 ad to the present day
#
# Original: Argentina As An Immigration Country
# Normalised: argentina as an immigration country
#
# Original: How Migration Affects The Country Of Emigration
# Normalised: how migration affects the country of emigration
#
# Original: Sociological Methods For The Study Of Immigrant Adjustement
# Normalised: sociological methods for the study of immigrant adjustement
#
# Original: Best Practices to Reduce Migration Pressures
# Normalised: best practices to reduce migration pressures
#
# Original: Averting Forced Migration in Countries in Transition
# Normalised: averting forced migration in countries in transition
#
# Original: Towards a Coherent Policy of Co-Development
# Normalised: towards a coherent policy of co-development
#
# Original: Best Practice Options: Yugoslavia
# Normalised: best practice options yugoslavia
#
# Original: Best Practice Options: Romania
# Normalised: best practice options romania
#
# Original: Best Practice Options: Mali
# Normalised: best practice options mali
#
# Original: Best Practice Options: Albania
# Normalised: best practice options albania
#
# Original: Best Practice Options: Turkey
# Normalised: best practice options turkey
#
# Original: Placing International Migration in the Context of the 3D's: Demography, Development, and Democracy
# Normalised: placing international migration in the context of the 3d demography development and democracy
#
# Original: The Economy, Development, and Work in the Final Report of the GCIM1
# Normalised: the economy development and work in the final report of the gcim1
#
# Original: Winners and Losers, Democrats and Demagogues, Welfare and Work: Commentary on the GCIM
# Normalised: winners and losers democrats and demagogues welfare and work commentary on the gcim
#
# Original: Human Smuggling as a Transnational Service Industry: Evidence from Austria LE TRAFIC ILLICITE D'ÊTRES HUMAINS, UNE INDUSTRIE DE SERVICETRANSNATIONALE: TÉMOIGNAGES D'AUTRICHE EL TRÁFICO ILÍCITO DE PERSONAS COMOINDUSTRIATRANSNACIONAL DE SERVICIOS: PRUEBAS APORTADAS PORAUSTRIA
# Normalised: human smuggling as a transnational service industry evidence from austria le trafic illicite d êtres humains une industrie de servicetransnationale témoignages d autriche el tráfico ilícito de personas comoindustriatransnacional de servicios pruebas aportadas poraustria
#
# Original: Schengen's Soft Underbelly? Irregular Migration and Human Smuggling across Land and Sea Borders to Italy LE TALON D'ACHILLE DE SCHENGEN ? LES MIGRATIONS ILLÉGALES ET LE TRAFIC ILLICITE D'ÊTRES HUMAINS VERS L'ITALIE PAR LES FRONTIÈRES TERRESTRES ET MARITIMES ¿EL PUNTO VULNERABLEDEL SCHENGEN? LA MIGRACIÓN IRREGULAR Y EL TRÁFICO ILÍCITO DE PERSONAS POR LAS FRONTERAS TERRESTRES Y MARÍTIMAS HACIA ITALIA
# Normalised: schengen soft underbelly irregular migration and human smuggling across land and sea borders to italy le talon d achille de schengen les migrations illégales et le trafic illicite d êtres humains vers l italie par les frontières terrestres et maritimes el punto vulnerabledel schengen la migración irregular y el tráfico ilícito de personas por las fronteras terrestres y marítimas hacia italia
#
# Original: Human Smuggling to and through Germany LE TRAFIC D'ÊTRE HUMAINS POUR ET PAR L'ALLEMAGNE EL TRÁFICO ILÍCITO DE PERSONAS HACIA ALEMANIA Y ATRAVÉS DEL PAÍS
# Normalised: human smuggling to and through germany le trafic d être humains pour et par l allemagne el tráfico ilícito de personas hacia alemania y através del país
#
# Original: Migrant's Agency in the Smuggling Process: The Perspectives of Smuggled Migrants in the Netherlands LE RÔLE DU MIGRANT DANS LE PROCESSUS DE PASSAGE CLANDESTIN: LE POINT DE VUE DE MIGRANTS CLANDESTINS AUX PAYS-BAS LA INFLUENCIA DE LOS MIGRANTES EN EL PROCESO DEL TRÁFICO ILÍCITO: PERSPECTIVAS DE LOS MIGRANTES OBJETO DE TRÁFICO ILÍCITO EN LOS PAÍSES BAJOS
# Normalised: migrant agency in the smuggling process the perspectives of smuggled migrants in the netherlands le rôle du migrant dans le processus de passage clandestin le point de vue de migrants clandestins aux pays-bas la influencia de los migrantes en el proceso del tráfico ilícito perspectivas de los migrantes objeto de tráfico ilícito en los países bajos
#
# Original: Migration as a Family Business: The Role of Personal Networks in the Mobility Phase of Migration LA MIGRATION EN TANT QU'ENTREPRISE FAMILIALE: LE RÔLE DES RÉSEAUX DE RELATIONS PERSONNELLES DANS LA PHASE DE MOBILITÉ DE LA MIGRATION. LAMIGRACIÓN COMO NEGOCIO FAMILIAR: EL PAPEL QUE DESEMPEÑAN LAS REDES PERSONALES EN LAFASE DE MOVILIDAD DE LAMIGRACIÓN
# Normalised: migration as a family business the role of personal networks in the mobility phase of migration la migration en tant qu entreprise familiale le rôle des réseaux de relations personnelles dans la phase de mobilité de la migration lamigración como negocio familiar el papel que desempeñan las redes personales en lafase de movilidad de lamigración
#
# Original: The Impact of Migration on Growth and Ageing of the Population in a New Receiving Country: The Case of Greece
# Normalised: the impact of migration on growth and ageing of the population in a new receiving country the case of greece
#
# Original: Canadian Immigration: Policy and Trends in the 1960s
# Normalised: canadian immigration policy and trends in the 1960s
#
# Original: A Model of Professional Adaptation of Refugees: The Cuban Case in the U.S. 1959-1970*
# Normalised: a model of professional adaptation of refugees the cuban case in the us 1959-1970
#
# Original: Cuban Architects and Engineers in the United States
# Normalised: cuban architects and engineers in the united states
#
# Original: Changes in the Composition and SEctoral Distribution of Migrant Workers in West Germany 1960-1972
# Normalised: changes in the composition and sectoral distribution of migrant workers in west germany 1960-1972
#
# Original: ICEM The very Essence of its Existence*
# Normalised: icem the very essence of its existence
#
# Original: Le Cime: Le sens de son existence*
# Normalised: le cime le sens de son existence
#
# Original: El Cime: El sentido de su existencia*
# Normalised: el cime el sentido de su existencia
#
# Original: Immigration as an essential Element for the Development of Latin America*
# Normalised: immigration as an essential element for the development of latin america
#
# Original: Determinants of Migration: The Highly Skilled*
# Normalised: determinants of migration the highly skilled
#
# Original: The Influence of the Ethnic Association on the Assimilation of its Immigrant Members
# Normalised: the influence of the ethnic association on the assimilation of its immigrant members
#
# Original: Less than Human? Diaspora, Disease and the Question of Citizenship
# Normalised: less than human diaspora disease and the question of citizenship
#
# Original: Migrants, Settlers and Colonists: The Biopolitics of Displaced Bodies
# Normalised: migrants settlers and colonists the biopolitics of displaced bodies
#
# Original: Contagion and its Guises: Inequalities and Disease among Tibetan Exiles in India
# Normalised: contagion and its guises inequalities and disease among tibetan exiles in india
#
# Original: Pachedu-Zenzele in the Diaspora: Promoting Sexual Health Amongst Zimbabweans in England
# Normalised: pachedu-zenzele in the diaspora promoting sexual health amongst zimbabweans in england
#
# Original: Diaspora and Health? Traditional Medicine and Culture in a Mexican Migrant Community
# Normalised: diaspora and health traditional medicine and culture in a mexican migrant community
#
# Original: The Birth of the African-Irish Diaspora: Pregnancy and Post-Natal Experiences of African Immigrant Women in Ireland
# Normalised: the birth of the african-irish diaspora pregnancy and post-natal experiences of african immigrant women in ireland
#
# Original: Complaints, Sensitivities and Responsibility: An Ethnographic Investigation into the Debates Concerning the Care of Bangladeshi Mothers in the East End
# Normalised: complaints sensitivities and responsibility an ethnographic investigation into the debates concerning the care of bangladeshi mothers in the east end
#
# Original: International Migration Policies: 1950-2000
# Normalised: international migration policies 1950-2000
#
# Original: International Migration and State Sovereignty in an Integrating Europe
# Normalised: international migration and state sovereignty in an integrating europe
#
# Original: Regional Organizations and Intra-Regional Migration in Sub-Saharan Africa: Challenges and Prospects
# Normalised: regional organizations and intra-regional migration in sub-saharan africa challenges and prospects
#
# Original: Informal but Effective: Regional Consultative Processes as a Tool in Managing Migration
# Normalised: informal but effective regional consultative processes as a tool in managing migration
#
# Original: New Approaches to Asylum?
# Normalised: new approaches to asylum
#
# Original: Replacement Migration: the wave of the future?
# Normalised: replacement migration the wave of the future
#
# Original: The Mobility of Entrepreneurs and Capital: Taiwanese Capital-Linked Migration
# Normalised: the mobility of entrepreneurs and capital taiwanese capital-linked migration
#
# Original: Refugee Women in Europe: Some Aspects of the Legal and Policy Dimensions
# Normalised: refugee women in europe some aspects of the legal and policy dimensions
#
# Original: Chipping Away at the Fortress: Unions, Immigration and the Transnational Labour Market
# Normalised: chipping away at the fortress unions immigration and the transnational labour market
#
# Original: He Came, He Saw, He Stayed. Guest Worker Programmes and the Issue of Non-Return
# Normalised: he came he saw he stayed guest worker programmes and the issue of non-return
#
# Original: The Receipt of Transfer Payments by Immigrants in Sweden
# Normalised: the receipt of transfer payments by immigrants in sweden
#
# Original: The Occupational Attainment of Immigrant Groups in Australia
# Normalised: the occupational attainment of immigrant groups in australia
#
# Original: Gender and Migration: West Indians in Comparative Perspective
# Normalised: gender and migration west indians in comparative perspective
#
# Original: Individual versus Household Migration Decision Rules: Gender and Marital Status Differences in Intentions to Migrate in South Africa
# Normalised: individual versus household migration decision rules gender and marital status differences in intentions to migrate in south africa
#
# Original: Migration, Motherhood, Marriage: Cross-Cultural Adaptation of North American Immigrant Mothers in Israel
# Normalised: migration motherhood marriage cross-cultural adaptation of north american immigrant mothers in israel
#
# Original: The Integration of Immigrants in Northern Sweden: A Case Study of the Municipality of Strömsund
# Normalised: the integration of immigrants in northern sweden a case study of the municipality of strömsund
#
# Original: The Europeanisation of Integration Policies
# Normalised: the europeanisation of integration policies
#
# Original: Poles Apart? EU Enlargement and the Labour Market Outcomes of Immigrants in the United Kingdom
# Normalised: poles apart eu enlargement and the labour market outcomes of immigrants in the united kingdom
#
# Original: EU Integration & Emigration Consequences: The Case of Lithuania
# Normalised: eu integration emigration consequences the case of lithuania
#
# Original: Statistical Analysis of the Emigration Flow from Greece
# Normalised: statistical analysis of the emigration flow from greece
#
# Original: The Determinants of Modern Maltese Emigration
# Normalised: the determinants of modern maltese emigration
#
# Original: Manpower Assessment and Planning
# Normalised: manpower assessment and planning
#
# Original: Differentiation of Capital and International Labor Migration: Constructing a Working Hypothesis
# Normalised: differentiation of capital and international labor migration constructing a working hypothesis
#
# Original: Recent European Immigration to the Chicago Metropolitan Area
# Normalised: recent european immigration to the chicago metropolitan area
#
# Original: THE TENTH ANNIVERSARY OF ICEM
# Normalised: the tenth anniversary of icem
#
# Original: EUROPEAN MULTILATERAL ORGANIZATIONS CONCERNED WITH THE MOVEMENT OF WORKERS
# Normalised: european multilateral organizations concerned with the movement of workers
#
# Original: REVERSAL OF DIRECTION IN TRADITIONAL MIGRATION: In the case of Europe and North Africa
# Normalised: reversal of direction in traditional migration in the case of europe and north africa
#
# Original: Migration, Displacement, and Violence: Prosecuting Romanian Street Children at the Paris Palace of Justice
# Normalised: migration displacement and violence prosecuting romanian street children at the paris palace of justice
#
# Original: The AIDS Epidemic and Migrants in South Asia and South-East Asia
# Normalised: the aids epidemic and migrants in south asia and south-east asia
#
# Original: Rights of Foreign Workers and the Politics of Migration in South-East and East Asia
# Normalised: rights of foreign workers and the politics of migration in south-east and east asia
#
# Original: Organizing the Unorganizable: Unions, NGOs, and Indonesian Migrant Labour
# Normalised: organizing the unorganizable unions ngos and indonesian migrant labour
#
# Original: Nationality Matters: SARS and Foreign Domestic Workers' Rights in Taiwan Province of China
# Normalised: nationality matters sars and foreign domestic workers rights in taiwan province of china
#
# Original: The Trafficking of Migrant Workers: What are the Links Between Labour Trafficking and Corruption?
# Normalised: the trafficking of migrant workers what are the links between labour trafficking and corruption
#
# Original: The Multilevel Approach to Promoting Asian Migrant Workers' Rights: The MFA Experience
# Normalised: the multilevel approach to promoting asian migrant workers rights the mfa experience
#
# Original: International Migration in a Changing World
# Normalised: international migration in a changing world
#
# Original: A Comparative Illustration of the Life-cycle of Economic Migration (1960 - 1980)
# Normalised: a comparative illustration of the life-cycle of economic migration 1960 - 1980
#
# Original: The Evolution of French Immigration Policy after May 1981
# Normalised: the evolution of french immigration policy after may 1981
#
# Original: Demographic Consequences of Migration Trends in Puerto Rico: 1950 - 1980
# Normalised: demographic consequences of migration trends in puerto rico 1950 - 1980
#
# Original: The Accession of Spain and Portugal to the EC from the Aspect of the Free Movement of Labour in an enlarged Common Labour Market
# Normalised: the accession of spain and portugal to the ec from the aspect of the free movement of labour in an enlarged common labour market
#
# Original: An Analytical Paradigm for the Analysis of National Inmigration Patterns
# Normalised: an analytical paradigm for the analysis of national inmigration patterns
#
# Original: Labour Migration in the Arab Gulf States: Patterns, Trends and Prospects*
# Normalised: labour migration in the arab gulf states patterns trends and prospects
#
# Original: Family Class Immigrants to Canada 1981-1984: Part 2: Some Aspects of Social Adaptation*
# Normalised: family class immigrants to canada 1981-1984 part 2 some aspects of social adaptation
#
# Original: Chinese Migration and Settlement in a Thai Village
# Normalised: chinese migration and settlement in a thai village
#
# Original: The Expenditure Patterns of the Canadian-born and the Foreign-born in Canada
# Normalised: the expenditure patterns of the canadian-born and the foreign-born in canada
#
# Original: The Interpreter in Cross-Cultural Therapy
# Normalised: the interpreter in cross-cultural therapy
#
# Original: Labour Market Career among Young Finnish Immigrants in Sweden: A Longitudinal Study
# Normalised: labour market career among young finnish immigrants in sweden a longitudinal study
#
# Original: Refugees of Turkish Origin: “Coerced Immigrants” to Turkey since 1945
# Normalised: refugees of turkish origin coerced immigrants to turkey since 1945
#
# Original: Human Resources Development in APEC and Australia's Migration and Training Policies
# Normalised: human resources development in apec and australia migration and training policies
#
# Original: A Model of Temporary Migration: The Egyptian Case
# Normalised: a model of temporary migration the egyptian case
#
# Original: Illegal Immigration and Local Labour Markets: The Case of Northern Greece
# Normalised: illegal immigration and local labour markets the case of northern greece
#
# Original: Emigration Dynamics In Mexico, Central America And The Caribbean.
# Normalised: emigration dynamics in mexico central america and the caribbean
#
# Original: A Cultural Economy Perspective on Service Sector Migration in the Global City: The Case of Hong Kong
# Normalised: a cultural economy perspective on service sector migration in the global city the case of hong kong
#
# Original: Home, Work and Community: Skilled International Migration and Expatriate Women in Singapore
# Normalised: home work and community skilled international migration and expatriate women in singapore
#
# Original: Characteristics and Assimilation of Chinese Immigrants in the US Labour Market
# Normalised: characteristics and assimilation of chinese immigrants in the us labour market
#
# Original: The State, Refugees and Migration in Sub-Saharan Africa
# Normalised: the state refugees and migration in sub-saharan africa
#
# Original: Forced Migration and Destination Choice: Armenian Forced Settlers and Refugees in the Russian Federation
# Normalised: forced migration and destination choice armenian forced settlers and refugees in the russian federation
#
# Original: Resurgent Irish Immigration to the US in the 1980s and early 1990s: A Socio-demographic Profile
# Normalised: resurgent irish immigration to the us in the 1980s and early 1990s a socio-demographic profile
#
# Original: The Health Status and Health Beliefs of Two London Migrant Communities
# Normalised: the health status and health beliefs of two london migrant communities
#
# Original: Sexually Transmitted Diseases and Migration
# Normalised: sexually transmitted diseases and migration
#
# Original: Aids, Travel and Migration: Legal and Human Rights Aspects
# Normalised: aids travel and migration legal and human rights aspects
#
# Original: Canadian Immigrants and Criminality
# Normalised: canadian immigrants and criminality
#
# Original: Immigration and Ethnicity: The Case of Argentina
# Normalised: immigration and ethnicity the case of argentina
#
# Original: Predicting Vietnamese Refugee Adjustment to Western Canada
# Normalised: predicting vietnamese refugee adjustment to western canada
#
# Original: Bilateral Municipal Cooperation On Migrants. Return Ticket Kulu-Stockholm
# Normalised: bilateral municipal cooperation on migrants return ticket kulu-stockholm
#
# Original: Turkish Self-Employment In The Federal Republic Of Germany With Special Regard To Northrhine-Westphalia
# Normalised: turkish self-employment in the federal republic of germany with special regard to northrhine-westphalia
#
# Original: Immigrant Workers in an Emigrant Economy:: AN EXAMINATION OF REPLACEMENT MIGRATION IN THE MIDDLE EAST
# Normalised: immigrant workers in an emigrant economy an examination of replacement migration in the middle east
#
# Original: Reintegration of Circulating Families in Southwestern Puerto Rico*
# Normalised: reintegration of circulating families in southwestern puerto rico
#
# Original: Post-War Immigration in the United States and the State of Minnesota:: THE PROCESS OF ENTERING AN ALL-AMERICAN COMMUNITY
# Normalised: post-war immigration in the united states and the state of minnesota the process of entering an all-american community
#
# Original: Migrant Workers: A Passage from India to the Middle East: DEMOGRAPHIC AND SOCIAL-PSYCHOLOGICAL IMPLICATIONS AND POLICY CONSIDERATION
# Normalised: migrant workers a passage from india to the middle east demographic and social-psychological implications and policy consideration
#
# Original: International Migration and Falling into the Income 'Safety Net':: SOCIAL ASSISTANCE AMONG FOREIGN CITIZENS IN SWEDEN
# Normalised: international migration and falling into the income safety net social assistance among foreign citizens in sweden
#
# Original: International Migration and New Zealand Labour Markets
# Normalised: international migration and new zealand labour markets
#
# Original: Current Trends and Developments: PATTERNS AND FORMS OF IMMIGRANT PARTICIPATION AND REPRESENTATION AT THE LOCAL AND NATIONAL LEVELS IN WESTERN (CONTINENTAL) EUROPE1
# Normalised: current trends and developments patterns and forms of immigrant participation and representation at the local and national levels in western continental europe1
#
# Original: Information: JOINT STUDY ON THE ROLE OF INFORMATION IN THE REALIZATION OF THE HUMAN RIGHTS OF MIGRANT WORKERS
# Normalised: information joint study on the role of information in the realization of the human rights of migrant workers
#
# Original: INTERNATIONAL CO-OPERATION SEMINAR “EMIGRANT YOUTH” YOUTH RED CROSS CASTELDEFELS, BARCELONA (SPAIN) — MAY 25-31 1985
# Normalised: international co-operation seminar emigrant youth youth red cross casteldefels barcelona spain may 25-31 1985
#
# Original: Dr. Gunther Beyer (1 904- 1983)
# Normalised: dr gunther beyer 1 904- 1983
#
# Original: Migration between the United States and Canada: A Study of Labour Market Adjustment
# Normalised: migration between the united states and canada a study of labour market adjustment
#
# Original: Level of Living of Immigrants in Sweden: A comparison of Male and Female Immigraim from Finland and Yugoslavia with Swedes in Same Age and Occupational Groups
# Normalised: level of living of immigrants in sweden a comparison of male and female immigraim from finland and yugoslavia with swedes in same age and occupational groups
#
# Original: U. S. Immigration Policy: the Guestworker Option Revisited*
# Normalised: u s immigration policy the guestworker option revisited
#
# Original: Statistical Estimation of Socio-Economic Factors affecting Migration in W. Europe
# Normalised: statistical estimation of socio-economic factors affecting migration in w europe
#
# Original: Destinations of International Travel by the US. Population
# Normalised: destinations of international travel by the us population
#
# Original: IOM/UNFPA Project on Emigration Dynamics in Developing Countries
# Normalised: iom unfpa project on emigration dynamics in developing countries
#
# Original: Preliminary Analysis of Emigration Dynamics in Sub-Saharan Africa
# Normalised: preliminary analysis of emigration dynamics in sub-saharan africa
#
# Original: An Overview of Present and Future Emigration Dynamics in South Asia
# Normalised: an overview of present and future emigration dynamics in south asia
#
# Original: A Preliminary Analysis of Emigration Determinants in Mexico, Central America, Northern South America and the Caribbean 1
# Normalised: a preliminary analysis of emigration determinants in mexico central america northern south america and the caribbean
#
# Original: International Migration: Some Consequences for Urban Areas in Australia and New Zealand
# Normalised: international migration some consequences for urban areas in australia and new zealand
#
# Original: The Systems Approach to International Migration: An Application of Network Analysis Methods
# Normalised: the systems approach to international migration an application of network analysis methods
#
# Original: Recent Developments in East-West Migration: Turkey and the Petty Traders
# Normalised: recent developments in east-west migration turkey and the petty traders
#
# Original: Salvadorian Migration to the United States in the 1980s. What can we learn about it and from it ? 1
# Normalised: salvadorian migration to the united states in the 1980s what can we learn about it and from it
#
# Original: The Economic Role of Immigrant Wives in Hong Kong 1
# Normalised: the economic role of immigrant wives in hong kong
#
# Original: Implementation of Congressional Intent: A Study of Amnesty Policy and the Immigration and Naturalization Service
# Normalised: implementation of congressional intent a study of amnesty policy and the immigration and naturalization service
#
# Original: Immigration and Unemployment in Australia
# Normalised: immigration and unemployment in australia
#
# Original: Is Migration Supply - or Demand - Determined?. Some remarks on the ideological use of economic language
# Normalised: is migration supply - or demand - determined some remarks on the ideological use of economic language
#
# Original: BASSLER, Gerhard P. Sanctuary Denied: Refugees from the Third Reich and Newfoundland Immigration Policy, 1906-1949
# Normalised: bassler gerhard p sanctuary denied refugees from the third reich and newfoundland immigration policy 1906-1949
#
# Original: Immigrant Fertility Patterns in Canada, 1961-1986*
# Normalised: immigrant fertility patterns in canada 1961-1986
#
# Original: British Emigrants to New Zealand: their Motives and Expectations
# Normalised: british emigrants to new zealand their motives and expectations
#
# Original: Mortality Differentials among Immigrant Populations in Canada*
# Normalised: mortality differentials among immigrant populations in canada
#
# Original: Variations in Fertility and Earning Patterns among Immigrants in the United States, 1970-1980: Assimilation or Disruption?*
# Normalised: variations in fertility and earning patterns among immigrants in the united states 1970-1980 assimilation or disruption
#
# Original: Fertility Adaptation of Turkish and Moroccan Women in The Netherlands*
# Normalised: fertility adaptation of turkish and moroccan women in the netherlands
#
# Original: Long Term Demographic Effect of a Constant Stream of Immigration when the Population is not Reproducing Itself*
# Normalised: long term demographic effect of a constant stream of immigration when the population is not reproducing itself
#
# Original: Pregancy Outcomes In A Group Of Vietnamese Refugees In Hong Kong
# Normalised: pregancy outcomes in a group of vietnamese refugees in hong kong
#
# Original: Xviiith Annual Conference Of The European Group For The Study Of Deviance And Social Control And Coornhertliga On Race And Crime: What'S The Relation? Haarlem, September 1990
# Normalised: xviiith annual conference of the european group for the study of deviance and social control and coornhertliga on race and crime what s the relation haarlem september 1990
#
# Original: Post-War Labour Migration in Western Europe An Overview
# Normalised: post-war labour migration in western europe an overview
#
# Original: Transients and Settlers: Varieties of Caribbean Migrants and the Socio-Economic Implications of their Return
# Normalised: transients and settlers varieties of caribbean migrants and the socio-economic implications of their return
#
# Original: Realities of Life and Future Prospects within two Cultures
# Normalised: realities of life and future prospects within two cultures
#
# Original: Return Migration from Australia A Case Study
# Normalised: return migration from australia a case study
#
# Original: The Long Road from Nador to Brussels
# Normalised: the long road from nador to brussels
#
# Original: Adjustment Patterns of the Arab Internal Refugees in Israel
# Normalised: adjustment patterns of the arab internal refugees in israel
#
# Original: LABOR IMMIGRATION IN THE ARAB GULF STATES: PATTERNS, TRENDS AND PROBLEMS
# Normalised: labor immigration in the arab gulf states patterns trends and problems
#
# Original: INTERNATIONAL CONFERENCE ON 'NEW MIGRATION POLICIES IN EUROPE - THE RETURN OF LABOUR MIGRANTS, RE-EMIGRATION PROMOTION AND REINTEGRATION POLICIES' BONN, 23-25 SEPTEMBER 1985
# Normalised: international conference on new migration policies in europe - the return of labour migrants re-emigration promotion and reintegration policies bonn 23-25 september 1985
#
# Original: Best of Times, Worst of Times, and Occupational Mobility: The Case of Soviet Immigrants in Israel
# Normalised: best of times worst of times and occupational mobility the case of soviet immigrants in israel
#
# Original: Ethnic Return Migration: An Estonian Case
# Normalised: ethnic return migration an estonian case
#
# Original: The Unemployment Insurance Compensation Usage of Canada's Immigrants in Selected Provinces, 1981-1988
# Normalised: the unemployment insurance compensation usage of canada immigrants in selected provinces 1981-1988
#
# Original: Migrant Remittances in Greece and Portugal: Distribution by Country of Provenance and the Role of the Banking Presence
# Normalised: migrant remittances in greece and portugal distribution by country of provenance and the role of the banking presence
#
# Original: International Trade, Labour Migrations and Capital Flows: Long-Term Evidence for Australia, Canada, the United Kingdom and the United States
# Normalised: international trade labour migrations and capital flows long-term evidence for australia canada the united kingdom and the united states
#
# Original: Do Migrants Worsen the Current Account?
# Normalised: do migrants worsen the current account
#
# Original: Economic Adjustment of Refugees in Canada: A Case Study*
# Normalised: economic adjustment of refugees in canada a case study
#
# Original: National Background and Choice of Tertiary Education in Victoria1
# Normalised: national background and choice of tertiary education in victoria
#
# Original: Political Events 'At Home' and the Concept of Catharsis Naturalization among Refugees
# Normalised: political events at home and the concept of catharsis naturalization among refugees
#
# Original: European Migrant Absorption in Australia
# Normalised: european migrant absorption in australia
#
# Original: Salaries, Employment Opportunities and Migration of Engineers
# Normalised: salaries employment opportunities and migration of engineers
#
# Original: Economic Implications of the International Migration of High Level Manpower*
# Normalised: economic implications of the international migration of high level manpower
#
# Original: Effects of Professional Restrictions on Cuban Refugees in Selected Health Professions in the United States 1959-1969*
# Normalised: effects of professional restrictions on cuban refugees in selected health professions in the united states 1959-1969
#
# Original: United States Immigration Laws and the Brain Drain
# Normalised: united states immigration laws and the brain drain
#
# Original: Contestée: La circulation des élites*
# Normalised: contestée la circulation des élites
#
# Original: The Role of the Ethnic Community as a Reception Area for Italian Immigrants in Melbourne, Australia
# Normalised: the role of the ethnic community as a reception area for italian immigrants in melbourne australia
#
# Original: Global Economic Restructuring and International Migration:: Some observations based on the Mexican and Central American experience
# Normalised: global economic restructuring and international migration some observations based on the mexican and central american experience
#
# Original: United Kingdom Labour Emigration and Capital Exports 1816-1991
# Normalised: united kingdom labour emigration and capital exports 1816-1991
#
# Original: Becoming a New Citizen in an Immigration Country: Turks in Australia and Sweden and Some Comparative Implications
# Normalised: becoming a new citizen in an immigration country turks in australia and sweden and some comparative implications
#
# Original: An Optimized Model for Substitution of Expatriate Workforce in a Gulf-Council Country: The Kuwaiti Case
# Normalised: an optimized model for substitution of expatriate workforce in a gulf-council country the kuwaiti case
#
# Original: The Economic Determinants of Greek Return Migration to the Islands of the East Aegean
# Normalised: the economic determinants of greek return migration to the islands of the east aegean
#
# Original: The Relevance of Research on Emigration Dynamics for Policy Makers in Sub-Saharan Africa: The Iom/Unfpa Project, Analysis Of Present And Future Emigration Dynamics In Developing Countries
# Normalised: the relevance of research on emigration dynamics for policy makers in sub-saharan africa the iom unfpa project analysis of present and future emigration dynamics in developing countries
#
# Original: Environmentally-Induced Population Displacements And Environmental Impacts From Mass Migrations
# Normalised: environmentally-induced population displacements and environmental impacts from mass migrations
#
# Original: The Protection of Migrant Workers and International Labour Standards*
# Normalised: the protection of migrant workers and international labour standards
#
# Original: Manpower Export and Economic Development: Evidence from the Philippines*
# Normalised: manpower export and economic development evidence from the philippines
#
# Original: Family Class Immigrants to Canada. 1981-84: Part 1*
# Normalised: family class immigrants to canada 1981-84 part 1
#
# Original: Measures to Facilitate the Reintegration of Returning Migrant Workers. International Experiences*
# Normalised: measures to facilitate the reintegration of returning migrant workers international experiences
#
# Original: La Mobilité spatiale des immigrés et ses effets sociaux
# Normalised: la mobilité spatiale des immigrés et ses effets sociaux
#
# Original: Miscounting the Spanish Origin Population in the United States: Corrections to the 1970 Census and their Implications
# Normalised: miscounting the spanish origin population in the united states corrections to the 1970 census and their implications
#
# Original: The Economic Determinants of Canada's Multicultural Immigration
# Normalised: the economic determinants of canada multicultural immigration
#
# Original: Armenian Migration, Settlement and Adjustment in Australia
# Normalised: armenian migration settlement and adjustment in australia
#
# Original: Migration and Research Commitments: Long-term Effects of National Socialization
# Normalised: migration and research commitments long-term effects of national socialization
#
# Original: CURRENT EVENTS AND DEVELOPMENTS
# Normalised: current events and developments
#
# Original: Migration Pressure
# Normalised: migration pressure
#
# Original: A Definition of Migration Pressure Based on Demand Theory
# Normalised: a definition of migration pressure based on demand theory
#
# Original: Economic Internationalization:The New Migration in Japan and the United States
# Normalised: economic internationalization the new migration in japan and the united states
#
# Original: Improving the Contribution of Migrant Remittances to Development: The Experience of Asian Labour-exporting Countries
# Normalised: improving the contribution of migrant remittances to development the experience of asian labour-exporting countries
#
# Original: Nurse Mobility in Europe: Implications for the United Kingdom
# Normalised: nurse mobility in europe implications for the united kingdom
#
# Original: Ireland: An “Emigrant Nursery” in the World Economy
# Normalised: ireland an emigrant nursery in the world economy
#
# Original: Immigration as Capital Accumulation: The Impact of Business Immigration to Canada
# Normalised: immigration as capital accumulation the impact of business immigration to canada
#
# Original: Temporary versus Permanent Youth Brain Drain: Economic Implications
# Normalised: temporary versus permanent youth brain drain economic implications
#
# Original: Variation in Perspective: The Employment Success of Ethnic Minority Males in the Netherlands, 1988-2002
# Normalised: variation in perspective the employment success of ethnic minority males in the netherlands 1988-2002
#
# Original: International Migration and the Role of Remittances in Eastern Europe
# Normalised: international migration and the role of remittances in eastern europe
#
# Original: Refugees from Bosnia and Herzegovina in Serbia: A Study of Refugee Selectivity
# Normalised: refugees from bosnia and herzegovina in serbia a study of refugee selectivity
#
# Original: Studies in Serial Migration
# Normalised: studies in serial migration
#
# Original: Transatlantic Dialogue on Integration of Immigrant Children and Adolescents
# Normalised: transatlantic dialogue on integration of immigrant children and adolescents
#
# Original: Note from the Guest Editor
# Normalised: note from the guest editor
#
# Original: Trafficking: A Perspective from Asia
# Normalised: trafficking a perspective from asia
#
# Original: Trafficking and Human Smuggling: A European Perspective
# Normalised: trafficking and human smuggling a european perspective
#
# Original: Illegality of International Population Movements in Poland
# Normalised: illegality of international population movements in poland
#
# Original: Asylum Policies, Trafficking and Vulnerability
# Normalised: asylum policies trafficking and vulnerability
#
# Original: People for Sale: The Need for a Multidisciplinary Approach towards Human Trafficking
# Normalised: people for sale the need for a multidisciplinary approach towards human trafficking
#
# Original: The Role of the Voluntary Agencies in the Resettlement of Ugandan Asians in the U.S.A.
# Normalised: the role of the voluntary agencies in the resettlement of ugandan asians in the usa
#
# Original: The permanent Settlement of African Refugees
# Normalised: the permanent settlement of african refugees
#
# Original: Temporary Workers in the United States
# Normalised: temporary workers in the united states
#
# Original: Manpower Mobility: The Case of Turkey and West Germany
# Normalised: manpower mobility the case of turkey and west germany
#
# Original: Flows of Greek Out-Migration and Return Migration
# Normalised: flows of greek out-migration and return migration
#
# Original: The Effect of Economic Incentives on Return Migration
# Normalised: the effect of economic incentives on return migration
#
# Original: Asian Transnational Families in Transition: The Liminality of Simultaneity
# Normalised: asian transnational families in transition the liminality of simultaneity
#
# Original: Migration and Transnational Families in Fiji: Comparing Two Ethnic Groups
# Normalised: migration and transnational families in fiji comparing two ethnic groups
#
# Original: Asian Transnational Families in New Zealand: Dynamics and Challenges
# Normalised: asian transnational families in new zealand dynamics and challenges
#
# Original: Intergenerational Transnationalism: 1.5 Generation Asian Migrants in New Zealand1
# Normalised: intergenerational transnationalism 1 5 generation asian migrants in new zealand
#
# Original: Philippine Women on the Move: Marriage across Borders
# Normalised: philippine women on the move marriage across borders
#
# Original: Married to the Military: Filipinas Negotiating Transnational Families
# Normalised: married to the military filipinas negotiating transnational families
#
# Original: “Flexible Citizenship” or Familial Ties that Bind? Singaporean Transmigrants in London
# Normalised:  flexible citizenship or familial ties that bind singaporean transmigrants in london
#
# Original: Bengali-Speaking Families in Singapore: Home, Nation and the World
# Normalised: bengali-speaking families in singapore home nation and the world
#
# Original: Report of the Seminar on Migration and Development on the Polish-Ukrainian Border
# Normalised: report of the seminar on migration and development on the polish-ukrainian border
#
# Original: The Danish Cartoon Affair: Free Speech, Racism, Islamism, and Integration
# Normalised: the danish cartoon affair free speech racism islamism and integration
#
# Original: International Migration and Gender in Latin America: A Comparative Analysis MIGRATION INTERNATIONALE ET PARITÉ DES SEXES EN AMÉRIQUE LATINE : UNE ANALYSE COMPARATIVE LA MIGRACIÓN INTERNACIONAL Y EL GÉNERO EN AMÉRICA LATINA: UN ANÁLISIS COMPARATIVO
# Normalised: international migration and gender in latin america a comparative analysis migration internationale et parité des sexes en amérique latine une analyse comparative la migración internacional y el género en américa latina un análisis comparativo
#
# Original: Graduate Overeducation and its Effects among Recently Arrived Immigrants to Australia: A Longitudinal Survey L'ACCUMULATION DE DIPLÔMES ET SES EFFETS CHEZ LES IMMIGRÉS RÉCEMMENT ARRIVÉS EN AUSTRALIE : ENQUÊTE LONGITUDINALE LOS GRADUADOS CON VARIOS DIPLOMAS Y SUS EFECTOS EN LOS INMIGRANTES RECIÉN LLEGADOS A AUSTRALIA: UNA ENCUESTA LONGITUDINAL
# Normalised: graduate overeducation and its effects among recently arrived immigrants to australia a longitudinal survey l accumulation de diplômes et ses effets chez les immigrés récemment arrivés en australie enquête longitudinale los graduados con varios diplomas y sus efectos en los inmigrantes recién llegados a australia una encuesta longitudinal
#
# Original: The New Latino South and the Challenge to American Public Education LE NOUVEAU SUD LATIN ET LE DÉFI POSÉÁ L'ÉDUCATION PUBLIQUE AMÉRICAINE EL NUEVO SUR LATINO Y EL RETO QUE ELLO PLANTEA A LA EDUCACIÓN PÚBLICA
# Normalised: the new latino south and the challenge to american public education le nouveau sud latin et le défi poséá l éducation publique américaine el nuevo sur latino y el reto que ello plantea a la educación pública
#
# Original: Professional Nigerian Women, Household Economy, and Immigration Decisions1 FEMMES CADRES DU NIGÉRIA, ÉCONOMIE DOMESTIQUE ET MIGRATION MUJERES PROFESIONALES NIGERIANAS, ECONOMÍA DEL HOGAR Y LA DECISIÓN DE EMIGRAR
# Normalised: professional nigerian women household economy and immigration decisions femmes cadres du nigéria économie domestique et migration mujeres profesionales nigerianas economía del hogar y la decisión de emigrar
#
# Original: What is Love? The Materiality of Care in Ghanaian Transnational Families
# Normalised: what is love the materiality of care in ghanaian transnational families
#
# Original: The War At Home: Affective Economics and Transnationally Adoptive Families in the United States
# Normalised: the war at home affective economics and transnationally adoptive families in the united states
#
# Original: A Wanderer in a Distant Place: Tibetan Exile Youth, Literacy, and Emotion
# Normalised: a wanderer in a distant place tibetan exile youth literacy and emotion
#
# Original: Not in the Eyes of the Beholder: Envy Among Bolivian Migrants in Spain
# Normalised: not in the eyes of the beholder envy among bolivian migrants in spain
#
# Original: Deseos y Dolores : Mapping Desire, Suffering, and (Dis)loyalty within Transnational Partnerships
# Normalised: deseos y dolores mapping desire suffering and dis loyalty within transnational partnerships
#
# Original: Theorizing the Intimacies of Migration: Commentary on The Emotional Formations of Transnational Worlds
# Normalised: theorizing the intimacies of migration commentary on the emotional formations of transnational worlds
#
# Original: Social Capital is Associated with Earnings among Foreign-born Mexican Men but not Women in Los Angeles County
# Normalised: social capital is associated with earnings among foreign-born mexican men but not women in los angeles county
#
# Original: Predicting Earnings Among Immigrants To Canada: The Role Of Source Country
# Normalised: predicting earnings among immigrants to canada the role of source country
#
# Original: Fostering Free Movement of Persons in West Africa: Achievements, Constraints, and Prospects for Intraregional Migration
# Normalised: fostering free movement of persons in west africa achievements constraints and prospects for intraregional migration
#
# Original: The Jewish Emigration from the Former Soviet Union to Germany
# Normalised: the jewish emigration from the former soviet union to germany
#
# Original: Identity Patterns among Immigrants from the Former Soviet Union in Israel: Assimilation vs. Ethnic Formation
# Normalised: identity patterns among immigrants from the former soviet union in israel assimilation vs ethnic formation
#
# Original: Ethnic Communities and Ethnic Organizations Reconsidered: South-East Asians and Eastern Europeans in Chicago
# Normalised: ethnic communities and ethnic organizations reconsidered south-east asians and eastern europeans in chicago
#
# Original: Chinese Women as Transnational Migrants: Gender and Class in Global Migration Narratives
# Normalised: chinese women as transnational migrants gender and class in global migration narratives
#
# Original: High-level Dialogue on Migration and Development
# Normalised: high-level dialogue on migration and development
#
# Original: Local Hybridity among Absorbing Institutions HYBRIDITÉ LOCALE PARMI LES INSTITUTIONS D'ASSIMILATION HIBRIDACIÓN LOCAL EN ENTIDADES DE ABSORCIÓN
# Normalised: local hybridity among absorbing institutions hybridité locale parmi les institutions d assimilation hibridación local en entidades de absorción
#
# Original: Integration into the Australian Labour Market: The Experience of Three “Visibly Different” Groups of Recently Arrived Refugees1 INTÉGRATION DANS LE MARCHÉ DU TRAVAIL AUSTRALIEN : L'EXPÉRIENCE DE TROIS GROUPES « VISIBLEMENT DIFFÉRENTS » DE RÉFUGIÉS RÉCEMMENT ARRIVÉS INTEGRACIÓN EN EL MERCADO LABORAL AUSTRALIANO: LA EXPERIENCIA DE TRES GRUPOS “VISIBLEMENTE DISTINTOS” DE REFUGIADOS RECIÉN LLEGADOS
# Normalised: integration into the australian labour market the experience of three visibly different groups of recently arrived refugees intégration dans le marché du travail australien l expérience de trois groupes visiblement différents de réfugiés récemment arrivés integración en el mercado laboral australiano la experiencia de tres grupos visiblemente distintos de refugiados recién llegados
#
# Original: “I too was an Immigrant”: An Analysis of Differing Modes of Mobilization in Two Bronx Mexican Migrant Organizations1 “J' AI ÉTÉ UN IMMIGRANT MOIAUSSI”: ANALYSE DES DIFFÉRENTS TYPES DE MOBILISATION AU SEIN DE DEUX ORGANISATIONS DE MIGRANTS MEXICAINS DU BRONX “YO TAMBIÉN FUI INMIGRANTE”: UN ANÁLISIS DE LOS MODOS DE MOVILIZACIÓN DIVERGENTES DE DOS ORGANIZACIONES DE MIGRANTES MEXICANOS EN EL BRONX
# ...
# Normalised: migrants in an irregular situation in the federal republic of germany the psycho-social situation of unaccompanied minors from areas of armed conflict in berlin west
#
# Original: Undocumented Migration in Hong Kong (Specific Measures taken to reduce the Flow of Undocumented Migrants)
# Normalised: undocumented migration in hong kong specific measures taken to reduce the flow of undocumented migrants
#
# Original: Migrant Workers in Asean: A Review of Issues and Implications for Government Policies
# Normalised: migrant workers in asean a review of issues and implications for government policies
#
# Original: Migration into the United States: Perceptions of and Responses to Controlled and Uncontrolled Migration
# Normalised: migration into the united states perceptions of and responses to controlled and uncontrolled migration
#
# Original: Enforcement Aspects of Canadian Immigration Law: Protection of the basic. Human Rights of Undocumented Migrants
# Normalised: enforcement aspects of canadian immigration law protection of the basic human rights of undocumented migrants
#
# Original: Arab Labour Migration: A Review of Trends and Issues
# Normalised: arab labour migration a review of trends and issues
#
# Original: Present Realities and Future Prospects among Greek Returners
# Normalised: present realities and future prospects among greek returners
#
# Original: The Model of Place Utility Revisited
# Normalised: the model of place utility revisited
#
# Original: Facing Changes and Making Choices: Unintended Turkish Immigrant Settlement in Australia
# Normalised: facing changes and making choices unintended turkish immigrant settlement in australia
#
# Original: Reversing the Flow: Agricultural Development and Changing Migration Patterns in Rural Maharashtra
# Normalised: reversing the flow agricultural development and changing migration patterns in rural maharashtra
#
# Original: The Distinction between Skills Based and Qualifications Based Procedures for Recognizing Migrants' Professional Skills*
# Normalised: the distinction between skills based and qualifications based procedures for recognizing migrants professional skills
#
# Original: Does “Smarter” Lead to Safer? An Assessment of the US Border Accords with Canada and Mexico
# Normalised: does smarter lead to safer an assessment of the us border accords with canada and mexico
#
# Original: Patterns of Immigrant Occupational Attainment in a Longitudinal Survey
# Normalised: patterns of immigrant occupational attainment in a longitudinal survey
#
# Original: Attitudes of Botswana Citizens toward Immigrants: Signs of Xenophobia?
# Normalised: attitudes of botswana citizens toward immigrants signs of xenophobia
#
# Original: Family Change and Economic Well-being in Canada: The Case of Recent Immigrant Families with Children
# Normalised: family change and economic well-being in canada the case of recent immigrant families with children
#
# Original: Economic Integration among Children of Israeli Immigrants in the United States
# Normalised: economic integration among children of israeli immigrants in the united states
#
# Original: The Impact of Immigration Policy on Indian Contract Migrants: The Case of the United Arab Emirates
# Normalised: the impact of immigration policy on indian contract migrants the case of the united arab emirates
#
# Original: Transatlantic Dialogue on Terrorism and International Migration
# Normalised: transatlantic dialogue on terrorism and international migration
#
# Original: Immigrants and Refugees: Their Similarities, Differences, and Needs
# Normalised: immigrants and refugees their similarities differences and needs
#
# Original: A Map Analysis of Middle East Immigrants in Detroit and Suburbs, 1961-1974
# Normalised: a map analysis of middle east immigrants in detroit and suburbs 1961-1974
#
# Original: Centripetal and Centrifugal Residential Movement. The Case of Dutch Immigrants in Auckland, New Zealand
# Normalised: centripetal and centrifugal residential movement the case of dutch immigrants in auckland new zealand
#
# Original: Exploring “Illegal” and “Irregular” Migrants' Lived Experiences of Law and State Power
# Normalised: exploring illegal and irregular migrants lived experiences of law and state power
#
# Original: Toward a Critical Phenomenology of “Illegality”: State Power, Criminalization, and Abjectivity among Undocumented Migrant Workers in Tel Aviv, Israel
# Normalised: toward a critical phenomenology of illegality state power criminalization and abjectivity among undocumented migrant workers in tel aviv israel
#
# Original: “Oaxacans Like to Work Bent Over”: The Naturalization of Social Suffering among Berry Farm Workers
# Normalised:  oaxacans like to work bent over the naturalization of social suffering among berry farm workers
#
# Original: “Everyone with Eyes Can See the Problem”: Moral Citizens and the Space of Irish Nationhood
# Normalised:  everyone with eyes can see the problem moral citizens and the space of irish nationhood
#
# Original: The Emergence of Pro-Regularization Movements in Western Europe
# Normalised: the emergence of pro-regularization movements in western europe
#
# Original: Battling for Survival, Battling for Moral Clarity: “Illegality” and Illness in the Everyday Struggles of Undocumented HIV+ Women Migrant Workers in Tel Aviv
# Normalised: battling for survival battling for moral clarity illegality and illness in the everyday struggles of undocumented hiv women migrant workers in tel aviv
#
# Original: Irregular Workers or Ethnic Kin? Post-1990s Labour Migration from Bulgaria to Turkey
# Normalised: irregular workers or ethnic kin post-1990s labour migration from bulgaria to turkey
#
# Original: Out-laws: Deportees, Desire, and “The Law”
# Normalised: out-laws deportees desire and the law
#
# Original: The Condition of Illegality
# Normalised: the condition of illegality
#
# Original: Grounding Immigrant Rights Movements in the Everyday Experience of Migration
# Normalised: grounding immigrant rights movements in the everyday experience of migration
#
# Original: International Migration and Social Mobility* An Australian Case Study
# Normalised: international migration and social mobility an australian case study
#
# Original: Les nouvelles tǎches du CIME l'Emigration sélective
# Normalised: les nouvelles tǎches du cime l emigration sélective
#
# Original: The Australian Character in the Eyes of Polish Immigrants in Western Australia
# Normalised: the australian character in the eyes of polish immigrants in western australia
#
# Original: Immigrants' Search for cultural Identity
# Normalised: immigrants search for cultural identity
#
# Original: A Shipboard Study of some British born Immigrants returning to the United Kingdom from Australia*
# Normalised: a shipboard study of some british born immigrants returning to the united kingdom from australia
#
# Original: Hay Que Importar Tecnologia
# Normalised: hay que importar tecnologia
#
# Original: Will There be 28 Million Australians BY 2000
# Normalised: will there be 28 million australians by 2000
#
# Original: Current U.S. Immigration Legislation: Analysis and Comment*
# Normalised: current us immigration legislation analysis and comment
#
# Original: Cuban Lawyers: Ten Years Later*
# Normalised: cuban lawyers ten years later
#
# Original: Greek and Polish Refugee Settlers in New Zealand - 1944-1968
# Normalised: greek and polish refugee settlers in new zealand - 1944-1968
#
# Original: Language - A Passport to Successful Immigrant Adjustment? The Quebec Experience
# Normalised: language - a passport to successful immigrant adjustment the quebec experience
#
# Original: Refugee Asylum in the United States: How the Law was Changed to Admit Displaced Persons
# Normalised: refugee asylum in the united states how the law was changed to admit displaced persons
#
# Original: A Matrix of Human Movement
# Normalised: a matrix of human movement
#
# Original: Expellees and 'Voluntary' Refugees from Less-developed Lands
# Normalised: expellees and voluntary refugees from less-developed lands
#
# Original: Turks and Yugoslavs: Guests or New Berliners?
# Normalised: turks and yugoslavs guests or new berliners
#
# Original: A Project of Social Work with Cypriot Immigrants in London
# Normalised: a project of social work with cypriot immigrants in london
#
# Original: Latinoamericanos en Europa, Aspectos Demogràficos Examinados a la Luz de Antecedentes Censales de Algunos Países Seleccionados
# Normalised: latinoamericanos en europa aspectos demogràficos examinados a la luz de antecedentes censales de algunos países seleccionados
#
# Original: Selection and Preparation of Applicants for Emigration to Australia*
# Normalised: selection and preparation of applicants for emigration to australia
#
# Original: Is Foreign Labour Complementary or Competitive (in Terms of Skill) With Native Born Labour? The Canadian Case, 1911-1941*
# Normalised: is foreign labour complementary or competitive in terms of skill with native born labour the canadian case 1911-1941
#
# Original: Migration of the Aged Population*
# Normalised: migration of the aged population
#
# Original: Subjective Assimilation among Latvian Adolescents: Effects of Ethnic Schools and Perception of Value Systems 1
# Normalised: subjective assimilation among latvian adolescents effects of ethnic schools and perception of value systems
#
# Original: Impact of the Group of Co-migrants on Strategies of Acculturation: Towards an Expansion of the Berry Model
# Normalised: impact of the group of co-migrants on strategies of acculturation towards an expansion of the berry model
#
# Original: Post-urbanism, Incorporation, and Migration
# Normalised: post-urbanism incorporation and migration
#
# Original: The Integration of Immigrants in Sweden: a Model for the European Union?
# Normalised: the integration of immigrants in sweden a model for the european union
#
# Original: Voting and Social Inclusion in Sweden
# Normalised: voting and social inclusion in sweden
#
# Original: When Will the Russians Come? On Post-Soviet Immigration and Integration in Sweden
# Normalised: when will the russians come on post-soviet immigration and integration in sweden
#
# Original: The Native-Immigrant Income Gap among the Self-Employed in Sweden
# Normalised: the native-immigrant income gap among the self-employed in sweden
#
# Original: Immigrants' Returns to Schooling in Sweden
# Normalised: immigrants returns to schooling in sweden
#
# Original: Asylum Seekers and Undocumented Migrants' Increased Social Rights in Sweden
# Normalised: asylum seekers and undocumented migrants increased social rights in sweden
#
# Original: The Territorial Composition of Italian Emigration to Australia 1876 to 1962*
# Normalised: the territorial composition of italian emigration to australia 1876 to 1962
#
# Original: Some Consequences of Structural Changes in Agriculture and of Technological Changes in other Economic Sectors of Europe
# Normalised: some consequences of structural changes in agriculture and of technological changes in other economic sectors of europe
#
# Original: The Cultural Influence of Government Agencies on New Rural Settlement
# Normalised: the cultural influence of government agencies on new rural settlement
#
# Original: Some Features of Immigration in France and in Europe
# Normalised: some features of immigration in france and in europe
#
# Original: Immigrant Participation in an Australian Community*
# Normalised: immigrant participation in an australian community
#
# Original: An Australian view of ICEM
# Normalised: an australian view of icem
#
# Original: Dutch Settlements in Brazil*
# Normalised: dutch settlements in brazil
#
# Original: Immigration from Western Countries in Israel
# Normalised: immigration from western countries in israel
#
# Original: Integration of a Group of Dutch Settlers in British Columbia
# Normalised: integration of a group of dutch settlers in british columbia
#
# Original: Constantes en la emigration española a ultramar
# Normalised: constantes en la emigration española a ultramar
#
# Original: The Migration of Professionals: Theories and Typologies
# Normalised: the migration of professionals theories and typologies
#
# Original: Europe and the Immigration of Highly Skilled Labour
# Normalised: europe and the immigration of highly skilled labour
#
# Original: Shifting Paradigms of Globalization: The Twenty-first Century Transition Towards Generics in Skilled Migration from India
# Normalised: shifting paradigms of globalization the twenty-first century transition towards generics in skilled migration from india
#
# Original: Structuration of Indian Information Technology Professionals' Migration to Australia: An Ethnographic Study
# Normalised: structuration of indian information technology professionals migration to australia an ethnographic study
#
# Original: Network Approach versus Brain Drain: Lessons from the Diaspora
# Normalised: network approach versus brain drain lessons from the diaspora
#
# Original: Trends in Latin American Skilled Migration: “Brain Drain” or “Brain Exchange”?
# Normalised: trends in latin american skilled migration brain drain or brain exchange
#
# Original: Transnationalizing Families: Canadian Immigration Policy and the Spatial Fragmentation of Care-giving among Latin American Newcomers1
# Normalised: transnationalizing families canadian immigration policy and the spatial fragmentation of care-giving among latin american newcomers
#
# Original: Language Background, Ethno-Racial Origin, and Academic Achievement of Students at a Canadian University
# Normalised: language background ethno-racial origin and academic achievement of students at a canadian university
#
# Original: Immigrants working with co-ethnics: Who are they and how do they fare?
# Normalised: immigrants working with co-ethnics who are they and how do they fare
#
# Original: The Evolution of the Temporary Protection Visa Regime in Australia
# Normalised: the evolution of the temporary protection visa regime in australia
#
# Original: Lobbying to Stay: the Chinese Students' Campaign to Stay in Australia
# Normalised: lobbying to stay the chinese students campaign to stay in australia
#
# Original: The Impact of Immigrant Status on Home Ownership in Australia
# Normalised: the impact of immigrant status on home ownership in australia
#
# Original: The Migration of Westerners to Thailand: An Unusual Flow From Developed to Developing World
# Normalised: the migration of westerners to thailand an unusual flow from developed to developing world
#
# Original: The Thai Government's Repatriation and Reintegration Programmes: Responding to Trafficked Female Commercial Sex Workers from the Greater Mekong Subregion
# Normalised: the thai government repatriation and reintegration programmes responding to trafficked female commercial sex workers from the greater mekong subregion
#
# Original: On Impacts of Comparative Policy Analysis. Immigration to Israel:What other Countries can Learn
# Normalised: on impacts of comparative policy analysis immigration to israel what other countries can learn
#
# Original: Distribution, Inequality and Concentration of Incomeamong Older Immigrants in Canada
# Normalised: distribution inequality and concentration of incomeamong older immigrants in canada
#
# Original: The Colour of Poverty: A Study of the Poverty of Ethnic and Immigrant Groups in Canada
# Normalised: the colour of poverty a study of the poverty of ethnic and immigrant groups in canada
#
# Original: Peopling Skilled International Migration: Indian Doctors in the UK
# Normalised: peopling skilled international migration indian doctors in the uk
#
# Original: Ecological Succession and Asian Immigrants in Australia
# Normalised: ecological succession and asian immigrants in australia
#
# Original: OVERSEAS MIGRATION TO AND FROM AUSTRALIA, 1947-1961
# Normalised: overseas migration to and from australia 1947-1961
# Original: ECONOMIC AND SOCIAL REPERCUSSIONS OF SPANISH EMIGRATION TO COUNTRIES OVERSEAS
# Normalised: economic and social repercussions of spanish emigration to countries overseas
#
# Original: HOW MIGRATION AFFECTS THE COUNTRY OF IMMIGRATION
# Normalised: how migration affects the country of immigration

# %% [markdown]
# ### Word Frequency Lists
#
# We start with a quick look at individual word frequencies for the first 20 titles to get an insight in some easy that need preprossing.

# %%
from collections import Counter # import to count word frequencies


# count frequencies of individual words
uni_freq = Counter()

for title in titles[:20]:
    # normalise the title using the steps described above
    title = normalise_title(title)
    # .split(' ') splits the title into chunks wherever there is a whitespace
    terms = title.split(' ')
    # count each term in the sentence, excluding 'empty' words
    uni_freq.update([term for term in terms if term != ''])

# Show the 25 most common words and their frequencies
for term, freq in uni_freq.most_common(25):
    print(f'{term: <30}{freq: >5}')
# Out:
# the                              15
# of                               13
# migration                        10
# and                               7
# in                                6
# a                                 5
# to                                5
# country                           3
# study                             3
# with                              2
# countries                         2
# review                            2
# international                     2
# development                       2
# empirical                         2
# brain                             2
# drain                             2
# as                                2
# an                                2
# immigrants                        2
# religious                         2
# for                               2
# immigration                       2
# best                              2
# community                         1

# %% [markdown]
# #### Stopwords and Content Words
#
# Now we notice that the most frequent words are stopwords. We can use a standard stopword list provided by [NLTK](http://www.nltk.org) to remove those from the frequency lists to focus on the content words.
#
# Since there are publications in English, French and Spanish, we use the stopword lists of all three languages.

# %%
from collections import Counter # import to count word frequencies
import re # import to remove punctuation
from nltk.corpus import stopwords # import to remove stopwords

stopwords_en = stopwords.words('english')
stopwords_fr = stopwords.words('french')
stopwords_sp = stopwords.words('spanish')
stopwords_all = stopwords_en + stopwords_fr + stopwords_sp

print('The first 10 English stopwords:', stopwords_en[:10])
print('The first 10 French stopwords:', stopwords_fr[:10])
print('The first 10 Spanish stopwords:', stopwords_sp[:10])
print('\nTotal number of distinct stopwords:', len(stopwords_all))
# Out:
# The first 10 English stopwords: ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your']
# The first 10 French stopwords: ['au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle']
# The first 10 Spanish stopwords: ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se']
#
# Total number of distinct stopwords: 621

# %%
# count frequencies of individual words
uni_freq = Counter()

for title in titles[:20]:
    # normalise the title using the steps described above
    title = normalise_title(title)
    # .split(' ') splits the title into chunks wherever there is a whitespace
    terms = title.split(' ')
    # remove stopwords
    terms = [term for term in terms if term not in stopwords_all]
    # count each term in the sentence, excluding 'empty' words
    uni_freq.update([term for term in terms if term != ''])

for term, freq in uni_freq.most_common(25):
    print(f'{term: <30}{freq: >5}')
# Out:
# migration                        10
# country                           3
# study                             3
# countries                         2
# review                            2
# international                     2
# development                       2
# empirical                         2
# brain                             2
# drain                             2
# immigrants                        2
# religious                         2
# immigration                       2
# best                              2
# community                         1
# services                          1
# out-migration                     1
# europe                            1
# agreements                        1
# migrant-sending                   1
# global                            1
# south                             1
# critical                          1
# asia                              1
# exploring                         1

# %% [markdown]
# Now we have a list of mostly content words. Note that the stopwords list contains English stopwords, so common stopwords in other languages are not filtered out. We assume these are not very common so will leave them in for now.
#
# Now we repeat the the frequency counting for all 1183 titles, instead of the first 20.

# %%
# count frequencies of individual words
uni_freq = Counter()

for title in titles:
    # normalise the title using the steps described above
    title = normalise_title(title)
    # .split(' ') splits the title into chunks wherever there is a whitespace
    terms = title.split(' ')
    # remove stopwords
    terms = [term for term in terms if term not in stopwords_all]
    # count each term in the sentence, excluding 'empty' words
    uni_freq.update([term for term in terms if term != ''])

for term, freq in uni_freq.most_common(25):
    print(f'{term: <30}{freq: >5}')
# Out:
# migration                       363
# immigrants                      110
# migrants                         91
# immigration                      86
# international                    79
# labour                           74
# case                             70
# migrant                          68
# australia                        68
# new                              60
# social                           58
# policy                           57
# united                           56
# immigrant                        55
# refugees                         54
# states                           52
# workers                          51
# countries                        50
# emigration                       50
# economic                         48
# return                           47
# canada                           46
# study                            45
# women                            45
# among                            41

# %% [markdown]
# #### Word Bigrams
#
# Next, we look at combinations of two words. Individual words can have quite different meanings in different contexts. Two neighbouring words in a title tend to contextualise each other, so convey more meaning.
#
# We create word bigrams in the following way:
#
# - we split the normalised title into individual words
# - we create bigrams for each two adjacent words, so 'evidence on brain drain' results in three bigrams:
#     - 'evidence on', 'on brain', 'brain drain'
# - we remove all bigrams in which either the first or the second word is a stopword, assuming that the stopword convey little contextual information.
#
# First we look at how this process transforms a title to a list of bigrams, and discuss how that affects frequencies.

# %%
for title in titles[:20]:
    # normalise the title using the steps described above
    title = normalise_title(title)
    print('Title:', title)
    # .split(' ') splits the title into chunks wherever there is a whitespace
    terms = title.split(' ')
    # get all pairs of subsequent title words
    bigrams = list(zip(terms[:-1], terms[1:]))
    print('\nAll bigrams:', [' '.join(bigram) for bigram in bigrams])
    # remove all bigrams for which the first or second word is a stopword
    bigram_terms = [' '.join(bigram) for bigram in bigrams if bigram[0] not in stopwords_all and bigram[1] not in stopwords_all]
    print('\nFiltered bigrams:', bigram_terms)
    print('\n')
# Out:
# Title: community services and out-migration
#
# All bigrams: ['community services', 'services and', 'and out-migration']
#
# Filtered bigrams: ['community services']
#
#
# Title: europe migration agreements with migrant-sending countries in the global south a critical review
#
# All bigrams: ['europe migration', 'migration agreements', 'agreements with', 'with migrant-sending', 'migrant-sending countries', 'countries in', 'in the', 'the global', 'global south', 'south a', 'a critical', 'critical review']
#
# Filtered bigrams: ['europe migration', 'migration agreements', 'migrant-sending countries', 'global south', 'critical review']
#
#
# Title: international migration and development in asia exploring knowledge frameworks
#
# All bigrams: ['international migration', 'migration and', 'and development', 'development in', 'in asia', 'asia exploring', 'exploring knowledge', 'knowledge frameworks']
#
# Filtered bigrams: ['international migration', 'asia exploring', 'exploring knowledge', 'knowledge frameworks']
#
#
# Title: theoretical considerations and empirical evidence on brain drain grounding the review of albania and bulgaria experience
#
# All bigrams: ['theoretical considerations', 'considerations and', 'and empirical', 'empirical evidence', 'evidence on', 'on brain', 'brain drain', 'drain grounding', 'grounding the', 'the review', 'review of', 'of albania', 'albania and', 'and bulgaria', 'bulgaria experience']
#
# Filtered bigrams: ['theoretical considerations', 'empirical evidence', 'brain drain', 'drain grounding', 'bulgaria experience']
#
#
# Title: causes challenges and prospects of brain drain the case of eritrea
#
# All bigrams: ['causes challenges', 'challenges and', 'and prospects', 'prospects of', 'of brain', 'brain drain', 'drain the', 'the case', 'case of', 'of eritrea']
#
# Filtered bigrams: ['causes challenges', 'brain drain']
#
#
# Title: a desire to return to the country of birth as a function of language preference an empirical study with iranian immigrants in the united states
#
# All bigrams: ['a desire', 'desire to', 'to return', 'return to', 'to the', 'the country', 'country of', 'of birth', 'birth as', 'as a', 'a function', 'function of', 'of language', 'language preference', 'preference an', 'an empirical', 'empirical study', 'study with', 'with iranian', 'iranian immigrants', 'immigrants in', 'in the', 'the united', 'united states']
#
# Filtered bigrams: ['language preference', 'empirical study', 'iranian immigrants', 'united states']
#
#
# Title: religious status and drug-use behaviour among former soviet union immigrants
#
# All bigrams: ['religious status', 'status and', 'and drug-use', 'drug-use behaviour', 'behaviour among', 'among former', 'former soviet', 'soviet union', 'union immigrants']
#
# Filtered bigrams: ['religious status', 'drug-use behaviour', 'behaviour among', 'among former', 'former soviet', 'soviet union', 'union immigrants']
#
#
# Title:  reconsidering the study of international migration a way forward for macrostructural migration research
#
# All bigrams: [' reconsidering', 'reconsidering the', 'the study', 'study of', 'of international', 'international migration', 'migration a', 'a way', 'way forward', 'forward for', 'for macrostructural', 'macrostructural migration', 'migration research', 'research ']
#
# Filtered bigrams: [' reconsidering', 'international migration', 'way forward', 'macrostructural migration', 'migration research', 'research ']
#
#
# Title: the new usa immigration law
#
# All bigrams: ['the new', 'new usa', 'usa immigration', 'immigration law']
#
# Filtered bigrams: ['new usa', 'usa immigration', 'immigration law']
#
#
# Title: post-war migration to switzerland
#
# All bigrams: ['post-war migration', 'migration to', 'to switzerland']
#
# Filtered bigrams: ['post-war migration']
#
#
# Title: the decline in religious participation of migrants
#
# All bigrams: ['the decline', 'decline in', 'in religious', 'religious participation', 'participation of', 'of migrants']
#
# Filtered bigrams: ['religious participation']
#
#
# Title: the repatriation of french algerians 1962-1963
#
# All bigrams: ['the repatriation', 'repatriation of', 'of french', 'french algerians', 'algerians 1962-1963']
#
# Filtered bigrams: ['french algerians', 'algerians 1962-1963']
#
#
# Title: the migration problem and the encyclical mater et magistra historical development of the moral aspects of human migration from 1500 ad to the present day
#
# All bigrams: ['the migration', 'migration problem', 'problem and', 'and the', 'the encyclical', 'encyclical mater', 'mater et', 'et magistra', 'magistra historical', 'historical development', 'development of', 'of the', 'the moral', 'moral aspects', 'aspects of', 'of human', 'human migration', 'migration from', 'from 1500', '1500 ad', 'ad to', 'to the', 'the present', 'present day']
#
# Filtered bigrams: ['migration problem', 'encyclical mater', 'magistra historical', 'historical development', 'moral aspects', 'human migration', '1500 ad', 'present day']
#
#
# Title: argentina as an immigration country
#
# All bigrams: ['argentina as', 'as an', 'an immigration', 'immigration country']
#
# Filtered bigrams: ['immigration country']
#
#
# Title: how migration affects the country of emigration
#
# All bigrams: ['how migration', 'migration affects', 'affects the', 'the country', 'country of', 'of emigration']
#
# Filtered bigrams: ['migration affects']
#
#
# Title: sociological methods for the study of immigrant adjustement
#
# All bigrams: ['sociological methods', 'methods for', 'for the', 'the study', 'study of', 'of immigrant', 'immigrant adjustement']
#
# Filtered bigrams: ['sociological methods', 'immigrant adjustement']
#
#
# Title: best practices to reduce migration pressures
#
# All bigrams: ['best practices', 'practices to', 'to reduce', 'reduce migration', 'migration pressures']
#
# Filtered bigrams: ['best practices', 'reduce migration', 'migration pressures']
#
#
# Title: averting forced migration in countries in transition
#
# All bigrams: ['averting forced', 'forced migration', 'migration in', 'in countries', 'countries in', 'in transition']
#
# Filtered bigrams: ['averting forced', 'forced migration']
#
#
# Title: towards a coherent policy of co-development
#
# All bigrams: ['towards a', 'a coherent', 'coherent policy', 'policy of', 'of co-development']
#
# Filtered bigrams: ['coherent policy']
#
#
# Title: best practice options yugoslavia
#
# All bigrams: ['best practice', 'practice options', 'options yugoslavia']
#
# Filtered bigrams: ['best practice', 'practice options', 'options yugoslavia']

# %% [markdown]
# Now we process all titles and count how often each word bigram occurs. The 25 most frequent bigrams are displayed for analysis.

# %%
# count frequencies of individual words
bi_freq = Counter()

for title in titles:
    # normalise the title using the steps described above
    title = normalise_title(title)
    # .split(' ') splits the title into chunks wherever there is a whitespace
    terms = title.split(' ')
    # get all pairs of subsequent title words
    bigrams = list(zip(terms[:-1], terms[1:]))
    # remove all bigrams for which the first or second word is a stopword
    bigram_terms = [' '.join(bigram) for bigram in bigrams if bigram[0] not in stopwords_all and bigram[1] not in stopwords_all]
    # count the occurrence of each bigram
    bi_freq.update(bigram_terms)


for term, freq in bi_freq.most_common(25):
    print(f'{term: <30}{freq: >5}')
# Out:
# international migration          51
# united states                    47
# labour market                    21
# labour migration                 20
# case study                       19
# migrant workers                  18
# brain drain                      17
# emigration dynamics              17
# return migration                 15
# immigration policy               13
# developing countries             13
# human trafficking                13
# migrant women                    13
# new zealand                      12
# middle east                      10
# former soviet                     9
# foreign workers                   9
# latin american                    9
# soviet union                      8
# sub-saharan africa                8
# hong kong                         8
# among immigrants                  8
# migration policy                  8
# asylum seekers                    8
# irregular migration               7

# %% [markdown]
# Now, 'international migration' is the most common two-word combination, followed by 'United States', 'labour market', 'labour migration', 'case study', 'migrant workers' and 'brain drain'.
#
# It is no surprise that bigrams containing the word 'migration' or 'migrant' are frequent, but the bigrams result in meaningful distinctions like 'labour migration' versus 'return migration' and 'migrant workers' versus 'migrant women'.

# %% [markdown]
# #### Assessing the Impact of Normalisation

# %%
# count frequencies of individual words
bi_freq = Counter()

for title in titles:
    # .split(' ') splits the title into chunks wherever there is a whitespace
    terms = title.split(' ')
    # get all pairs of subsequent title words
    bigrams = list(zip(terms[:-1], terms[1:]))
    # remove all bigrams for which the first or second word is a stopword
    bigram_terms = [' '.join(bigram) for bigram in bigrams if bigram[0] not in stopwords_all and bigram[1] not in stopwords_all]
    # count the occurrence of each bigram
    bi_freq.update(bigram_terms)


for term, freq in bi_freq.most_common(25):
    print(f'{term: <30}{freq: >5}')
# Out:
# International Migration          38
# The Case                         36
# United States                    30
# Labour Market                    19
# Case Study                       18
# Labour Migration                 15
# Emigration Dynamics              15
# The Impact                       14
# Return Migration                 12
# International Migration:         11
# The Role                         11
# Migrant Workers                  11
# Migration: The                   11
# Developing Countries             11
# Migrant Women                    11
# A Case                           10
# A Comparative                    10
# Human Trafficking                10
# Former Soviet                     9
# Foreign Workers                   9
# Brain Drain                       8
# Soviet Union                      8
# Immigration Policy                8
# Hong Kong                         8
# United States:                    8

# %% [markdown]
# #### Assessing the impact of removing bigrams with stopwords

# %%
# count frequencies of individual words
bi_freq = Counter()

for title in titles:
    # normalise the title using the steps described above
    title = normalise_title(title)
    # .split(' ') splits the title into chunks wherever there is a whitespace
    terms = title.split(' ')
    # remove stopwords before making bigrams
    terms = [term for term in terms if term not in stopwords_all]
    # get all pairs of subsequent title words
    bigrams = list(zip(terms[:-1], terms[1:]))
    # remove all bigrams for which the first or second word is a stopword
    bigram_terms = [' '.join(bigram) for bigram in bigrams]
    # count the occurrence of each bigram
    bi_freq.update(bigram_terms)


for term, freq in bi_freq.most_common(25):
    print(f'{term: <30}{freq: >5}')
# Out:
# international migration          51
# united states                    47
# labour market                    21
# labour migration                 20
# case study                       19
# migrant workers                  18
# brain drain                      17
# emigration dynamics              17
# return migration                 15
# immigration policy               13
# developing countries             13
# human trafficking                13
# migrant women                    13
# new zealand                      12
# middle east                      10
# former soviet                     9
# foreign workers                   9
# immigrants australia              9
# latin american                    9
# countries origin                  9
# migration development             8
# soviet union                      8
# sub-saharan africa                8
# immigrants canada                 8
# hong kong                         8

# %% [markdown]
# ### Analysing Title Words Per Decade
#
# The articles are published over a period of several decades, and there might be shifts in the discourse over time. A next step is to group uni-grams and bi-grams per decade, to visualise shifts.

# %% [markdown]
# The first step is to group the article titles per decade. We derive the decade from the year that the issue was published.

# %%
# adding a column per article with the publication decade
df['issue_decade'] = df.issue_pub_year.apply(lambda x: int(x/10) * 10 if not pd.isnull(x) else x)
# recreate the selection of the dataset with the new column
df_selected = df[(df.recurring_title == False) & (df.article_author.str.len() > 0)]

df_selected[['issue_pub_year', 'issue_decade']]
# Out:
#       issue_pub_year  issue_decade
# 0               2010          2010
# 1               2010          2010
# 2               2010          2010
# 3               2010          2010
# 4               2010          2010
# ...              ...           ...
# 1678            2000          2000
# 1679            2000          2000
# 1684            1962          1960
# 1685            1962          1960
# 1686            1962          1960
#
# [1183 rows x 2 columns]

# %% [markdown]
# The number of articles per decade shows that there is a slight dip in the 1970s, but after that increases per decade.

# %%
df_selected.issue_decade.value_counts().sort_index()
# Out:
# 1960    124
# 1970    109
# 1980    220
# 1990    267
# 2000    359
# 2010    104
# Name: issue_decade, dtype: int64

# %%
# make a list of all decades in the dataset
decades = sorted([int(decade) for decade in list(set(df_selected.issue_decade)) if not pd.isnull(decade)])
decades
# Out:
# [1960, 1970, 1980, 1990, 2000, 2010]

# %% [markdown]
# #### Analysing content words per decade

# %%
def make_title_unigram_term_list(title: str, stopwords):
    # normalise the title using the steps described above
    title = normalise_title(title)
    # .split(' ') splits the title into chunks wherever there is a whitespace
    terms = title.split(' ')
    # remove stopwords
    terms = [term for term in terms if term not in stopwords]
    return terms


for decade in decades:
    titles = list(df_selected[df_selected.issue_decade == decade].article_title)
    normalised_titles = [normalise_title(title) for title in titles]
    unigram_terms = [term for title in normalised_titles for term in make_title_unigram_term_list(title, stopwords_all)]
    unigram_freq = Counter(unigram_terms)
    print(decade)
    print('--------------------------')
    for term, freq in unigram_freq.most_common(25):
        print(f'{term: <30}{freq: >5}')
    print('\n\n')
# Out:
# 1960
# --------------------------
# migration                        29
# immigration                      16
# australia                        12
# emigration                       11
# immigrants                       10
# australian                        8
# development                       7
# european                          7
# social                            7
# immigrant                         6
# america                           6
# assimilation                      6
# international                     6
# country                           5
# europe                            5
# integration                       5
# refugees                          5
# economic                          5
# western                           5
# migrants                          4
# aspects                           4
# study                             4
# icem                              4
# latin                             4
# influence                         4
#
#
#
# 1970
# --------------------------
# migration                        23
# immigrants                       13
# immigration                      10
# refugees                         10
# united                            9
# states                            9
# economic                          7
# australia                         7
# new                               7
# cuban                             6
# population                        6
# adaptation                        5
# case                              5
# social                            5
# integration                       5
# canadian                          4
# policy                            4
# migrant                           4
# germany                           4
# european                          4
# international                     4
# manpower                          4
# greek                             4
# europe                            4
# zealand                           4
#
#
#
# 1980
# --------------------------
# migration                        70
# migrants                         24
# migrant                          23
# immigration                      22
# social                           20
# immigrants                       19
# international                    18
# women                            17
#                                  16
# states                           16
# countries                        16
# canada                           15
# labour                           14
# united                           14
# return                           14
# policy                           13
# trends                           13
# origin                           13
# effects                          13
# workers                          12
# case                             12
# -                                11
# situation                        11
# family                           10
# implications                     10
#
#
#
# 1990
# --------------------------
# migration                        92
# labour                           26
# international                    25
# emigration                       23
# immigrants                       22
# case                             21
# australia                        20
# immigration                      20
# migrants                         19
# united                           19
# dynamics                         16
# migrant                          16
# countries                        16
# states                           16
# new                              14
# workers                          14
# refugees                         13
# africa                           13
# canada                           13
# economic                         13
# study                            12
# development                      12
#                                  12
# immigrant                        12
# among                            11
#
#
#
# 2000
# --------------------------
# migration                       120
# immigrants                       34
#                                  29
# migrants                         27
# trafficking                      27
# labour                           25
# new                              24
# immigrant                        24
# international                    21
# case                             21
# migrant                          20
# australia                        20
# policy                           19
# human                            17
# among                            17
# israel                           17
# return                           17
# study                            16
# chinese                          16
# development                      15
# transnational                    15
# immigration                      14
# workers                          14
# refugees                         14
# social                           13
#
#
#
# 2010
# --------------------------
# migration                        29
#                                  17
# migrants                         13
# immigrants                       12
# transnational                    10
# case                              9
# integration                       8
# social                            7
# new                               7
# policy                            7
# european                          7
# asylum                            7
# among                             6
# irregular                         6
# trafficking                       6
# workers                           6
# sweden                            6
# international                     5
# return                            5
# union                             5
# women                             5
# participation                     5
# immigrant                         5
# remittances                       5
# political                         5

# %%
def make_title_bigram_term_list(title: str, stopwords):
    # first turn the title into a list of normalised words, but don't remove stopwords
    terms = make_title_unigram_term_list(title, [])
    # get all pairs of subsequent words in the title
    bigrams = list(zip(terms[:-1], terms[1:]))
    # remove all bigrams for which the first or second word is a stopword
    bigram_terms = [' '.join(bigram) for bigram in bigrams 
                    if bigram[0] not in stopwords and bigram[1] not in stopwords]
    return bigram_terms


for decade in decades:
    titles = list(df_selected[df_selected.issue_decade == decade].article_title)
    normalised_titles = [normalise_title(title) for title in titles]
    bigram_terms = [term for title in titles for term in make_title_bigram_term_list(title, stopwords_all)]
    bigram_freq = Counter(bigram_terms)
    print(decade)
    print('--------------------------')
    for term, freq in bigram_freq.most_common(25):
        print(f'{term: <30}{freq: >5}')
    print('\n\n')
# Out:
# 1960
# --------------------------
# latin america                     4
# brain drain                       3
# international migration           3
# western australia                 3
# migration affects                 2
# immigrants returning              2
# selective migration               2
# rural settlement                  2
# united states                     2
# polish immigrants                 2
# immigration policy                2
# new usa                           1
# usa immigration                   1
# immigration law                   1
# post-war migration                1
# religious participation           1
# french algerians                  1
# algerians 1962-1963               1
# migration problem                 1
# encyclical mater                  1
# magistra historical               1
# historical development            1
# moral aspects                     1
# human migration                   1
# 1500 ad                           1
#
#
#
# 1970
# --------------------------
# united states                     9
# new zealand                       4
# canadian immigration              3
# west germany                      3
# international migration           3
# brain drain                       3
# immigration policy                2
# professional adaptation           2
# states 1959-1969                  2
# italian immigrants                2
# melbourne australia               2
# ugandan asians                    2
# return migration                  2
# family migration                  2
# returning migrants                2
# vocational training               2
# migration policy                  2
# recent developments               2
# future prospects                  2
# human rights                      2
# cuban case                        1
# us 1959-1970                      1
# cuban architects                  1
# sectoral distribution             1
# migrant workers                   1
#
#
#
# 1980
# --------------------------
# united states                    13
# migrant women                    11
# international migration           9
# current trends                    6
# middle east                       5
# migrant workers                   5
# return migration                  5
# brain drain                       5
# labour market                     4
# labour migration                  4
# western europe                    4
# social effects                    4
# family structure                  4
# federal republic                  4
# undocumented migration            4
# second generation                 3
# receiving countries               3
# developing countries              3
# occupational mobility             3
# forms reasons                     3
# voluntarily decide                3
# labor migration                   2
# - 1980                            2
# immigration policy                2
# may 1981                          2
#
#
#
# 1990
# --------------------------
# international migration          18
# emigration dynamics              16
# united states                    14
# labour migration                 10
# south-north migration             7
# labour market                     6
# developing countries              6
# foreign workers                   6
# central america                   5
# sub-saharan africa                5
# return migration                  5
# hong kong                         4
# united kingdom                    4
# asylum seekers                    4
# case study                        4
# iom unfpa                         3
# unfpa project                     3
# south asia                        3
# new zealand                       3
# among immigrants                  3
# south africa                      3
# migrant workers                   3
# medical screening                 3
# special reference                 3
# northern greece                   2
#
#
#
# 2000
# --------------------------
# international migration          15
# human trafficking                10
# case study                        9
# labour market                     7
# migrant workers                   7
# united states                     7
# best practice                     6
# former soviet                     6
# practice options                  5
# tráfico ilícito                   5
# soviet union                      5
# migration-development nexus       5
# immigration policy                5
# labour migration                  5
# forced migration                  4
# human smuggling                   4
# brain drain                       4
# transnational families            4
# among immigrants                  4
# new york                          4
# migration policy                  4
# highly skilled                    4
# property restitution              4
# skilled migration                 4
# best practices                    3
#
#
#
# 2010
# --------------------------
# labour market                     4
# new immigrants                    4
# transnational political           4
# european union                    4
# international migration           3
# irregular migration               3
# human trafficking                 3
# latin american                    3
# brain drain                       2
# united states                     2
# social capital                    2
# earnings among                    2
# case study                        2
# migrant workers                   2
# market penalties                  2
# old receiving                     2
# receiving west                    2
# west european                     2
# european countries                2
# untold stories                    2
# irregular migrants                2
# political participation           2
# caribbean migrants                2
# migrants residing                 2
# political practices               2

# %% [markdown]
# ### Analysing Countries Mentioned in Titles
#
# We map countries to continents, as larger geographic units.
#
# In some titles, the nationality of a migrant group is mentioned, which differs from the country name. We add an analysis in which also nationalities are mapped to their respective country names and continents. E.g. `Polish` is mapped to `Poland` and `Europe`.
#
# We started with the countries and continents listed on the [World Atlas](https://www.worldatlas.com/cntycont.htm) website, and extended these several former countries (e.g. Soviet Union) and not formally-recognised countries (e.g. Kosovo, Palestina) as well as some larger regions (Caribbean, Latin America, Middle East). For the UK, we included England, Northern Ireland, Scotland and Wales, as these are also mentioned in some titles.
#
# For the nationalities, we used a list provided by Wikipedia ([List of adjectival and demonymic forms for countries and nations](https://en.wikipedia.org/w/index.php?title=List_of_adjectival_and_demonymic_forms_for_countries_and_nations&oldid=1004136953)).

# %%
from scripts.countries import CountryLookup, show_counts

lookup = CountryLookup()

titles = list(df_selected.article_title)

# First we count without nationalities
country_count, continent_count = lookup.count_countries_continents(titles, include_nationalities=False)


show_counts(country_count, continent_count)
# Out:
# Countries
# ----------------------------------
# Australia                       80
# United States                   56
# Canada                          46
# Israel                          40
# Germany                         19
# Sweden                          18
# India                           17
# Latin America                   15
# Mexico                          14
# Japan                           14
# Greece                          12
# New Zealand                     12
# Middle East                     11
# Cuba                            10
# Vietnam                         10
# Brazil                          10
# Turkey                           9
# Netherlands                      9
# China                            9
# Spain                            9
#
#
# Continents
# ----------------------------------
# Europe                         205
# Asia                           198
# North America                  129
# Oceania                         92
# Africa                          74
# South America                   47

# %%
# Next we count with nationalities included
country_count, continent_count = lookup.count_countries_continents(titles, include_nationalities=True)

show_counts(country_count, continent_count)
# Out:
# Countries
# ----------------------------------
# Australia                       80
# United States                   75
# Canada                          65
# Israel                          40
# China                           29
# Mexico                          25
# Germany                         23
# Greece                          23
# Turkey                          21
# Macau                           21
# Sweden                          20
# India                           17
# Netherlands                     16
# Italy                           15
# Latin America                   15
# Japan                           14
# Spain                           12
# New Zealand                     12
# France                          11
# United Kingdom                  11
#
#
# Continents
# ----------------------------------
# Europe                         270
# Asia                           233
# North America                  168
# Oceania                         92
# Africa                          80
# South America                   48

# %%
decades = [1960, 1970, 1980, 1990, 2000, 2010]

for decade in decades:
    print(decade)
    print('\n')
    titles = list(df_selected[df_selected.issue_decade == decade].article_title)
    country_count, continent_count = lookup.count_countries_continents(titles, include_nationalities=True)
    show_counts(country_count, continent_count)
    print('\n\n')
# Out:
# 1960
#
#
# Countries
# ----------------------------------
# Australia                       20
# United States                    7
# Canada                           5
# Latin America                    4
# United Kingdom                   4
# Brazil                           4
# France                           3
# Hungary                          3
# Italy                            3
# Netherlands                      3
# Greece                           2
# Norway                           2
# Poland                           2
# Germany                          2
# Israel                           2
# Spain                            2
# Switzerland                      1
# Algeria                          1
# Argentina                        1
# Malta                            1
#
#
# Continents
# ----------------------------------
# Europe                          35
# Oceania                         20
# North America                   11
# South America                    9
# Africa                           4
# Asia                             3
#
#
#
# 1970
#
#
# Countries
# ----------------------------------
# United States                   15
# Canada                           7
# Cuba                             7
# Australia                        7
# Germany                          4
# Greece                           4
# New Zealand                      4
# Italy                            3
# Israel                           3
# Latvia                           3
# Uganda                           2
# Turkey                           2
# Brazil                           2
# Japan                            2
# Russia                           1
# Malta                            1
# Taiwan                           1
# Chile                            1
# Norway                           1
# Venezuela                        1
#
#
# Continents
# ----------------------------------
# Europe                          27
# North America                   23
# Oceania                         11
# Asia                            11
# South America                    4
# Africa                           3
#
#
#
# 1980
#
#
# Countries
# ----------------------------------
# Canada                          21
# United States                   18
# Australia                       10
# Israel                           7
# Germany                          6
# Greece                           5
# Middle East                      5
# Spain                            4
# Sweden                           4
# Netherlands                      4
# France                           3
# Puerto Rico                      3
# India                            3
# Philippines                      3
# Argentina                        3
# China                            2
# Thailand                         2
# Macau                            2
# Caribbean                        2
# Armenia                          2
#
#
# Continents
# ----------------------------------
# Europe                          45
# North America                   42
# Asia                            29
# Oceania                         11
# South America                   10
# Africa                           4
#
#
#
# 1990
#
#
# Countries
# ----------------------------------
# Australia                       22
# United States                   16
# Canada                          14
# Turkey                          12
# Israel                          11
# Japan                           11
# Mexico                          10
# Greece                           9
# United Kingdom                   5
# India                            5
# Egypt                            4
# Caribbean                        4
# Hong Kong                        4
# Germany                          4
# Sweden                           3
# Singapore                        3
# China                            3
# Vietnam                          3
# New Zealand                      3
# Kuwait                           3
#
#
# Continents
# ----------------------------------
# Asia                            77
# Europe                          41
# North America                   40
# Africa                          27
# Oceania                         23
# South America                    8
#
#
#
# 2000
#
#
# Countries
# ----------------------------------
# China                           23
# Australia                       20
# Israel                          17
# Canada                          17
# Macau                           16
# United States                   14
# Mexico                          11
# India                            7
# Sweden                           7
# Germany                          6
# Turkey                           5
# Taiwan                           5
# Poland                           5
# Soviet Union                     5
# Vietnam                          5
# Denmark                          4
# Latin America                    4
# France                           4
# Italy                            3
# Netherlands                      3
#
#
# Continents
# ----------------------------------
# Asia                            99
# Europe                          81
# North America                   44
# Africa                          29
# Oceania                         25
# South America                    7
#
#
#
# 2010
#
#
# Countries
# ----------------------------------
# Sweden                           6
# United States                    5
# Netherlands                      4
# Italy                            4
# Spain                            3
# Thailand                         3
# Latin America                    3
# Iran                             2
# Ghana                            2
# Mexico                           2
# India                            2
# Caribbean                        2
# Ecuador                          2
# England                          2
# Poland                           2
# Albania                          1
# Bulgaria                         1
# Eritrea                          1
# Soviet Union                     1
# Bolivia                          1
#
#
# Continents
# ----------------------------------
# Europe                          41
# Asia                            14
# Africa                          13
# South America                   10
# North America                    8
# Oceania                          2

# %%
# Spreadsheets:
# - frequency lists 
# - titles + countries + direction + return yes/no
#
