# %% [markdown]
# ## Splitting records
#
# Some article records have multiple authors and affiliations. For author analysis, we want to split those records.

# %%
import pandas as pd

sage_records_file = '../data/sage-crawl-records.json'

# load the csv data into a data frame
df_sage = pd.read_json(sage_records_file)
# show the first and last records of the dataset to demonstrate what the records look like
#df_sage

# %%
df_sage.journal.value_counts()
# Out:
# International Migration Review    5505
# Name: journal, dtype: int64

# %%
wiley_records_file = '../data/wiley-IM-records.json'

# load the csv data into a data frame
df_wiley = pd.read_json(wiley_records_file)
# show the first and last records of the dataset to demonstrate what the records look like
#df_wiley

# %%
df_wiley.journal.value_counts()
# Out:
# International Migration    1629
# Migracion                    34
# Migration                    27
# Name: journal, dtype: int64

# %%
# Make sure same journal name is used throughout data set
df_wiley.journal = 'International Migration'
#df_wiley

# %% [markdown]
# ### Concatenating the two datasets
#
# The two datasets have the same columns, so we can merge and look for authors that appear in both datasets.
#
# We remove records for articles where the author is not specified. This leave 6340 out of 7195 articles.

# %%
# concatenate and make a single data frame
df = pd.concat([df_wiley, df_sage], ignore_index=True)

print('Number of articles in the combined dataset:', len(df))
print('Number of articles with no specified author:', len(df[df.article_author_index_name == '']))
print('Number of articles with specified author(s):', len(df[df.article_author_index_name != '']))
print('\n\n')
df = df[df.article_author_index_name != '']
df
# Out:
# Number of articles in the combined dataset: 7195
# Number of articles with no specified author: 855
# Number of articles with specified author(s): 6340
#                                           article_title  \
# 0                  Community Services and Out-Migration
# 1     Europe's Migration Agreements with Migrant-Sen...
# 2     International Migration and Development in Asi...
# 3     Theoretical Considerations and Empirical Evide...
# 4     Causes, Challenges and Prospects of Brain Drai...
# ...                                                 ...
# 7178   16 Turkey: Late Entrant into Europe's Work Force
# 7179        17 Yugoslavia: Emigration Out of Necessity?
# 7180             18 Japan: The Issue of Migrant Workers
# 7181      19 Post-Soviet Emigration: Today and Tomorrow
# 7183                                            Preface
#
#                                             article_doi  \
# 0     https://onlinelibrary.wiley.com/doi/10.1111/j....
# 1     https://onlinelibrary.wiley.com/doi/10.1111/j....
# 2     https://onlinelibrary.wiley.com/doi/10.1111/j....
# 3     https://onlinelibrary.wiley.com/doi/10.1111/j....
# 4     https://onlinelibrary.wiley.com/doi/10.1111/j....
# ...                                                 ...
# 7178  https://journals.sagepub.com/doi/pdf/10.1177/0...
# 7179  https://journals.sagepub.com/doi/pdf/10.1177/0...
# 7180  https://journals.sagepub.com/doi/pdf/10.1177/0...
# 7181  https://journals.sagepub.com/doi/pdf/10.1177/0...
# 7183  https://journals.sagepub.com/doi/pdf/10.1177/0...
#
#                                          article_author  \
# 0     Douglas S. Massey && Nathalie Williams && Will...
# 1     Aderanti Adepoju && Femke Van Noorloos && Anne...
# 2     Maruja M.B. Asis && Nicola Piper && Parvati Ra...
# 3                                   Nicholas P. Glytsos
# 4                                        Mussie Tessema
# ...                                                 ...
# 7178                                 Nermin Abadan-unat
# 7179              Silva Meznaric & Jadranka Caci-kumpes
# 7180                                     Masatoshi Muto
# 7181                                    Lilia Shevtsova
# 7183                                    Lydio F. Tomasi
#
#                               article_author_index_name  \
# 0     Massey, Douglas S && Williams, Nathalie && Axi...
# 1     Adepoju, Aderanti && van Noorloos, Femke && Zo...
# 2     Asis, Maruja MB && Piper, Nicola && Raghuram, ...
# 3                                   Glytsos, Nicholas P
# 4                                       Tessema, Mussie
# ...                                                 ...
# 7178                                Abadan-unat, Nermin
# 7179            Meznaric, Silva & Caci-kumpes, Jadranka
# 7180                                    Muto, Masatoshi
# 7181                                   Shevtsova, Lilia
# 7183                                    Tomasi, Lydio F
#
#                              article_author_affiliation article_page_range  \
# 0                                           &&  &&  &&                1-41
# 1                                               &&  &&               42-75
# 2                                               &&  &&              76-106
# 3                                                                  107-130
# 4                                                                  131-157
# ...                                                 ...                ...
# 7178                               University of Ankara            307-336
# 7179  Institute for Migration and Ethnic Studies Uni...            337-345
# 7180                 Ministry of Foreign Affairs, Tokyo            348-352
# 7181                   USSR Academy of Sciences, Moscow            353-369
# 7183                                                                 vii-x
#
#      article_pub_date  article_pub_year      issue_section  \
# 0       26 April 2010              2010  ORIGINAL ARTICLES
# 1       26 April 2010              2010  ORIGINAL ARTICLES
# 2       26 April 2010              2010  ORIGINAL ARTICLES
# 3       26 April 2010              2010  ORIGINAL ARTICLES
# 4       26 April 2010              2010  ORIGINAL ARTICLES
# ...               ...               ...                ...
# 7178      Jan 1, 1993              1993            Article
# 7179      Jan 1, 1993              1993            Article
# 7180      Jan 1, 1993              1993            Article
# 7181      Jan 1, 1993              1993            Article
# 7183      Jan 1, 1986              1986            Article
#
#                              journal volume    issue  \
# 0            International Migration     48        3
# 1            International Migration     48        3
# 2            International Migration     48        3
# 3            International Migration     48        3
# 4            International Migration     48        3
# ...                              ...    ...      ...
# 7178  International Migration Review     27  1_suppl
# 7179  International Migration Review     27  1_suppl
# 7180  International Migration Review     27  1_suppl
# 7181  International Migration Review     27  1_suppl
# 7183  International Migration Review     20  1_suppl
#
#                                             issue_title issue_page_range  \
# 0                 International Migration: Vol 48, No 3            1-193
# 1                 International Migration: Vol 48, No 3            1-193
# 2                 International Migration: Vol 48, No 3            1-193
# 3                 International Migration: Vol 48, No 3            1-193
# 4                 International Migration: Vol 48, No 3            1-193
# ...                                                 ...              ...
# 7178  International Migration Review - Volume 27, Nu...              NaN
# 7179  International Migration Review - Volume 27, Nu...              NaN
# 7180  International Migration Review - Volume 27, Nu...              NaN
# 7181  International Migration Review - Volume 27, Nu...              NaN
# 7183  International Migration Review - Volume 20, Nu...              NaN
#
#      issue_pub_date  issue_pub_year        publisher
# 0         June 2010            2010            Wiley
# 1         June 2010            2010            Wiley
# 2         June 2010            2010            Wiley
# 3         June 2010            2010            Wiley
# 4         June 2010            2010            Wiley
# ...             ...             ...              ...
# 7178   Jan 01, 1993            1993  Sage Publishing
# 7179   Jan 01, 1993            1993  Sage Publishing
# 7180   Jan 01, 1993            1993  Sage Publishing
# 7181   Jan 01, 1993            1993  Sage Publishing
# 7183   Jan 01, 1986            1986  Sage Publishing
#
# [6340 rows x 17 columns]

# %% [markdown]
# ## Clustering Author Names
#
# We want to see which authors published in both journals, and how often. This requires a number of transformations:
#
# 1. splitting records of multi-author papers into a record per author
# 2. normalising author names such that variant spellings are mapped to a single version.
#
# The latter step is always a risky operation, because using only the surface form of a name can results in two persons with similar names being considered as a single person. Given that this dataset narrowly focuses in only authors of articles in the two journals, we assume the chance that two authors have the same surname and initials is low.
#
#
# #### Splitting multi-author records

# %%
# Code adapted from https://stackoverflow.com/questions/50731229/split-cell-into-multiple-rows-in-pandas-dataframe

import numpy as np
from itertools import chain

# return list from series of comma-separated strings
def chainer(s):
    return list(chain.from_iterable(s.fillna('').str.split(' && ')))

# calculate lengths of splits
lens = df['article_author'].fillna('').str.split(' && ').map(len)

# create new dataframe, repeating or chaining as appropriate
df_split = pd.DataFrame({
    'journal': np.repeat(df['journal'], lens),
    'issue_pub_year': np.repeat(df['issue_pub_year'], lens),
    'article_author': chainer(df['article_author']),
    'article_author_index_name': chainer(df['article_author_index_name']),
    'article_author_affiliation': chainer(df['article_author_affiliation'])
})

df_split = df_split.reset_index(drop=True)
df_split
# Out:
#                              journal  issue_pub_year  \
# 0            International Migration            2010
# 1            International Migration            2010
# 2            International Migration            2010
# 3            International Migration            2010
# 4            International Migration            2010
# ...                              ...             ...
# 6769  International Migration Review            1993
# 6770  International Migration Review            1993
# 6771  International Migration Review            1993
# 6772  International Migration Review            1993
# 6773  International Migration Review            1986
#
#                              article_author  \
# 0                         Douglas S. Massey
# 1                         Nathalie Williams
# 2                          William G. Axinn
# 3                         Dirgha J. Ghimire
# 4                          Aderanti Adepoju
# ...                                     ...
# 6769                     Nermin Abadan-unat
# 6770  Silva Meznaric & Jadranka Caci-kumpes
# 6771                         Masatoshi Muto
# 6772                        Lilia Shevtsova
# 6773                        Lydio F. Tomasi
#
#                     article_author_index_name  \
# 0                           Massey, Douglas S
# 1                          Williams, Nathalie
# 2                            Axinn, William G
# 3                           Ghimire, Dirgha J
# 4                           Adepoju, Aderanti
# ...                                       ...
# 6769                      Abadan-unat, Nermin
# 6770  Meznaric, Silva & Caci-kumpes, Jadranka
# 6771                          Muto, Masatoshi
# 6772                         Shevtsova, Lilia
# 6773                          Tomasi, Lydio F
#
#                              article_author_affiliation
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 6769                               University of Ankara
# 6770  Institute for Migration and Ethnic Studies Uni...
# 6771                 Ministry of Foreign Affairs, Tokyo
# 6772                   USSR Academy of Sciences, Moscow
# 6773
#
# [6774 rows x 5 columns]

# %% [markdown]
# #### Normalising author names
#
# There is a lot of variation in how author names are represented. Sometimes with full first and middle names, sometime with only the first name or only initials, or the first name in full but the middle names as initials.
#
# We start from the author format where the surname is followed by the first and middle names (field `article_author_index_name`). We apply the following normalisation and mapping steps:
#
# 1. transform the `article_author_index_name` to title casing (meaning each initial character of a name part is uppercase and the rest is lowercase),
# 2. remove everything after the first letter that follows the surname,
# 3. transform all uses of `ij` to `y` as this Dutch and German names containing `ij` are sometimes spelled with `y`, e.g. `Gunther Beijer` vs. `Gunther Beyer`.

# %%
def acronym(string):
    if string == 'International Migration':
        return 'IM'
    else:
        return 'IMR'


def parse_surname(author_name: str):
    return author_name.split(',')[0].replace('ij', 'y').title()


def parse_surname_initial(author_name: str):
    if ',' not in author_name:
        return author_name
    surname = author_name.split(',')[0].replace('ij', 'y').title()
    initial = author_name.split(', ')[1][0]
    return f'{surname}, {initial}'


df_split['article_author_index_name'] = df_split['article_author_index_name'].str.title()
df_split['author_surname_initial'] = df_split.article_author_index_name.apply(parse_surname_initial)
df_split['issue_pub_decade'] = df_split.issue_pub_year.apply(lambda x: int(x/10)*10)

df_split.journal = df_split.journal.apply(acronym)

df_split
# Out:
#      journal  issue_pub_year                         article_author  \
# 0         IM            2010                      Douglas S. Massey
# 1         IM            2010                      Nathalie Williams
# 2         IM            2010                       William G. Axinn
# 3         IM            2010                      Dirgha J. Ghimire
# 4         IM            2010                       Aderanti Adepoju
# ...      ...             ...                                    ...
# 6769     IMR            1993                     Nermin Abadan-unat
# 6770     IMR            1993  Silva Meznaric & Jadranka Caci-kumpes
# 6771     IMR            1993                         Masatoshi Muto
# 6772     IMR            1993                        Lilia Shevtsova
# 6773     IMR            1986                        Lydio F. Tomasi
#
#                     article_author_index_name  \
# 0                           Massey, Douglas S
# 1                          Williams, Nathalie
# 2                            Axinn, William G
# 3                           Ghimire, Dirgha J
# 4                           Adepoju, Aderanti
# ...                                       ...
# 6769                      Abadan-Unat, Nermin
# 6770  Meznaric, Silva & Caci-Kumpes, Jadranka
# 6771                          Muto, Masatoshi
# 6772                         Shevtsova, Lilia
# 6773                          Tomasi, Lydio F
#
#                              article_author_affiliation  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 6769                               University of Ankara
# 6770  Institute for Migration and Ethnic Studies Uni...
# 6771                 Ministry of Foreign Affairs, Tokyo
# 6772                   USSR Academy of Sciences, Moscow
# 6773
#
#      author_surname_initial  issue_pub_decade
# 0                 Massey, D              2010
# 1               Williams, N              2010
# 2                  Axinn, W              2010
# 3                Ghimire, D              2010
# 4                Adepoju, A              2010
# ...                     ...               ...
# 6769         Abadan-Unat, N              1990
# 6770            Meznaric, S              1990
# 6771                Muto, M              1990
# 6772           Shevtsova, L              1990
# 6773              Tomasi, L              1980
#
# [6774 rows x 7 columns]

# %% [markdown]
# ### Looking at author overlap between journal
#
# There following 212 authors who have published in both journals:

# %%
g = df_split[df_split.author_surname_initial.isna() == False].groupby(['author_surname_initial', 'journal']).journal.count()
df_overlap = g.unstack('journal').fillna(0.0)
df_overlap[(df_overlap.IM > 0) & (df_overlap.IMR > 0)]
# Out:
# journal                   IM  IMR
# author_surname_initial
# Adepoju, A              11.0  1.0
# Afolayan, A              1.0  1.0
# Agadjanian, V            2.0  2.0
# Al-Qudsi, S              1.0  1.0
# Allen, R                 1.0  1.0
# ...                      ...  ...
# Young, C                 1.0  1.0
# Zhou, M                  1.0  5.0
# Zlotnik, H               2.0  7.0
# Zubrzycki, J             5.0  4.0
# Ögelman, N               1.0  3.0
#
# [212 rows x 2 columns]

# %% [markdown]
# There are 54 authors who published at least two articles in each journal. Here we see Gunther Beijer and and Jerzy Zubrzicki, who are also directly involved in the REMP publications:

# %%
g = df_split[df_split.author_surname_initial.isna() == False].groupby(['author_surname_initial', 'journal']).journal.count()
df_overlap = g.unstack('journal').fillna(0.0)
print('number of authors with at least two articles in both journals:', 
      len(df_overlap[(df_overlap.IM > 1) & (df_overlap.IMR > 1)]))

df_overlap[(df_overlap.IM > 1) & (df_overlap.IMR > 1)]
# Out:
# number of authors with at least two articles in both journals: 54
# journal                   IM   IMR
# author_surname_initial
# Agadjanian, V            2.0   2.0
# Appleyard, R            25.0   3.0
# Basok, T                 2.0   5.0
# Beenstock, M             3.0   2.0
# Bernard, W               6.0   7.0
# Beyer, G                16.0   3.0
# Brandon, P               2.0   2.0
# Burnley, I               2.0   3.0
# Böhning, W               4.0   7.0
# Carling, J               2.0   4.0
# Chiswick, B              3.0   9.0
# Clarke, H                2.0   2.0
# Drbohlav, D              2.0   2.0
# Findlay, A               4.0   2.0
# Gould, W                 2.0   3.0
# Hou, F                   2.0   2.0
# Hugo, G                  4.0   8.0
# Iredale, R               6.0   3.0
# Kats, R                  2.0   2.0
# Keely, C                14.0  14.0
# Khoo, S                  4.0   5.0
# Kunz, E                  3.0   4.0
# Lianos, T                4.0   2.0
# Lowell, B                3.0   2.0
# Marr, W                  4.0   2.0
# Martin, P               11.0  40.0
# Martin, S               11.0   3.0
# Massey, D                4.0   8.0
# Mazzucato, V             2.0   2.0
# Menjívar, C              2.0   2.0
# Michalowski, M           2.0   2.0
# Miller, M                3.0  27.0
# Miller, P                3.0   2.0
# Myers, G                 2.0   7.0
# Papademetriou, D         7.0   5.0
# Passaris, C              4.0   3.0
# Penninx, R               2.0   2.0
# Price, C                 2.0   9.0
# Reyneri, E               3.0   2.0
# Richardson, A            2.0   4.0
# Richmond, A              3.0  13.0
# Rogers, T                5.0   3.0
# Salt, J                  5.0   7.0
# Samuel, T                8.0   7.0
# Seccombe, I              4.0   2.0
# Semyonov, M              2.0   2.0
# Shah, N                  4.0   6.0
# Skeldon, R               3.0   3.0
# Stahl, C                 8.0   5.0
# Straubhaar, T            4.0   3.0
# Thomas, B                2.0   2.0
# Wong, L                  2.0   2.0
# Zlotnik, H               2.0   7.0
# Zubrzycki, J             5.0   4.0

# %%
print('Number of authors in both journals combined:', len(df_overlap))
print('Number of authors in International Migration:', len(df_overlap[df_overlap.IM > 0]))
print('Number of authors in International Migration Review:', len(df_overlap[df_overlap.IMR > 0]))
# Out:
# Number of authors in both journals combined: 3682
# Number of authors in International Migration: 1201
# Number of authors in International Migration Review: 2693

# %% [markdown]
# The 212 authors with articles in both journals represent 18% of all IM authors ($212 / 1201 = 0.18$) and 8% ($212 / 2693 = 0.08$) of all IMR authors.

# %%
print(round(212/1201, 2))
print(round(212/2693, 2))
# Out:
# 0.18
# 0.08

# %%
print('Number of persons who published multiple articles in IM:', len(df_overlap[df_overlap.IM > 1]))

print('Number of multi-IM authors who also published in IMR:', len(df_overlap[(df_overlap.IM > 1) & (df_overlap.IMR > 0)]))
# Out:
# Number of persons who published multiple articles in IM: 227
# Number of multi-IM authors who also published in IMR: 91

# %%
print('Number of persons who published multiple articles in IMR:', len(df_overlap[df_overlap.IMR > 1]))

print('Number of multi-IMR authors who also published in IM:', len(df_overlap[(df_overlap.IMR > 1) & (df_overlap.IM > 0)]))
# Out:
# Number of persons who published multiple articles in IMR: 769
# Number of multi-IMR authors who also published in IM: 109

# %%
print('IM:', len(df_overlap[df_overlap.IM > 1]) / len(df_overlap[df_overlap.IM > 0]))
print('IMR:', len(df_overlap[df_overlap.IMR > 1]) / len(df_overlap[df_overlap.IMR > 0]))

print('IM:', len(df_overlap[df_overlap.IM > 4]) / len(df_overlap[df_overlap.IM > 0]))
print('IMR:', len(df_overlap[df_overlap.IMR > 4]) / len(df_overlap[df_overlap.IMR > 0]))
# Out:
# IM: 0.18900915903413823
# IMR: 0.28555514296323803
# IM: 0.019150707743547043
# IMR: 0.05124396583735611

# %%
print(df_overlap[df_overlap.IMR > 1].shape)
df_overlap[df_overlap.IMR > 1].IM.value_counts()
# Out:
# (769, 2)
# 0.0     660
# 1.0      55
# 2.0      21
# 4.0      11
# 3.0       9
# 5.0       3
# 8.0       2
# 11.0      2
# 6.0       2
# 7.0       1
# 14.0      1
# 16.0      1
# 25.0      1
# Name: IM, dtype: int64

# %%
print(df_overlap[df_overlap.IM > 1].shape)
df_overlap[df_overlap.IM > 1].IMR.value_counts()
# Out:
# (227, 2)
# 0.0     136
# 1.0      37
# 2.0      21
# 3.0      10
# 7.0       6
# 4.0       4
# 5.0       4
# 8.0       2
# 9.0       2
# 6.0       1
# 13.0      1
# 27.0      1
# 40.0      1
# 14.0      1
# Name: IMR, dtype: int64

# %%
305/371
660/769
# Out:
# 0.8582574772431729

# %%
df_overlap.plot(kind='scatter', x='IM', y='IMR')
# Out:
# <AxesSubplot:xlabel='IM', ylabel='IMR'>

# %%
g = df_split[(df_split.author_surname_initial.isna() == False) & (df_split.author_surname_initial != '')].groupby(['author_surname_initial', 'journal']).journal.count()
df_overlap = g.unstack('journal').fillna(0.0)
df_overlap
# Out:
# journal                  IM  IMR
# author_surname_initial
# Abadan-Unat, N          0.0  6.0
# Abaka, E                0.0  1.0
# Abalos, D               0.0  1.0
# Abandan-Unat, N         0.0  1.0
# Abascal, M              0.0  1.0
# ...                     ...  ...
# Ávila, F                1.0  0.0
# Åkesson, L              1.0  0.0
# Åslund, O               0.0  1.0
# Ögelman, N              1.0  3.0
# Østergaard-Nielsen, E   0.0  1.0
#
# [3681 rows x 2 columns]

# %%
df_split[df_split.author_surname_initial.isna() == False]
# Out:
#      journal  issue_pub_year                         article_author  \
# 0         IM            2010                      Douglas S. Massey
# 1         IM            2010                      Nathalie Williams
# 2         IM            2010                       William G. Axinn
# 3         IM            2010                      Dirgha J. Ghimire
# 4         IM            2010                       Aderanti Adepoju
# ...      ...             ...                                    ...
# 6769     IMR            1993                     Nermin Abadan-unat
# 6770     IMR            1993  Silva Meznaric & Jadranka Caci-kumpes
# 6771     IMR            1993                         Masatoshi Muto
# 6772     IMR            1993                        Lilia Shevtsova
# 6773     IMR            1986                        Lydio F. Tomasi
#
#                     article_author_index_name  \
# 0                           Massey, Douglas S
# 1                          Williams, Nathalie
# 2                            Axinn, William G
# 3                           Ghimire, Dirgha J
# 4                           Adepoju, Aderanti
# ...                                       ...
# 6769                      Abadan-Unat, Nermin
# 6770  Meznaric, Silva & Caci-Kumpes, Jadranka
# 6771                          Muto, Masatoshi
# 6772                         Shevtsova, Lilia
# 6773                          Tomasi, Lydio F
#
#                              article_author_affiliation  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 6769                               University of Ankara
# 6770  Institute for Migration and Ethnic Studies Uni...
# 6771                 Ministry of Foreign Affairs, Tokyo
# 6772                   USSR Academy of Sciences, Moscow
# 6773
#
#      author_surname_initial  issue_pub_decade
# 0                 Massey, D              2010
# 1               Williams, N              2010
# 2                  Axinn, W              2010
# 3                Ghimire, D              2010
# 4                Adepoju, A              2010
# ...                     ...               ...
# 6769         Abadan-Unat, N              1990
# 6770            Meznaric, S              1990
# 6771                Muto, M              1990
# 6772           Shevtsova, L              1990
# 6773              Tomasi, L              1980
#
# [6774 rows x 7 columns]
