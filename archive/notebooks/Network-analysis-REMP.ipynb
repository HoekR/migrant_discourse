# %% [markdown]
# ## Analysis Migration Discourse as Social Networks
#
# Method:
# - generate networks per period, each person or organisation is a node
#     - **Shape**: different types of nodes have different shapes: organisation, academic, technocrat
#     - **Color**: use different colours to represent different nationalities, grey for unknown nationalities, black for organisations
#
#
# Vragen:
#
# - Beijer, G. Beijer en G.O.K. Beijer zijn dezelfde persoon?
# - sommige contributors van de studies staan niet in de personenlijst. Hoe categoriseren we die?

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# %pwd
# Out:
# '/Users/rikhoekstra/develop/migrant_discourse/archive/notebooks'

# %%
import os
os.listdir('.')
# Out:
# ['.DS_Store',
#  'IMR-title-analysis-marijn.ipynb',
#  'IM-title-analysis-marijn.ipynb',
#  'IMR_analysis.ipynb',
#  '.ipynb_checkpoints',
#  'IM-author-analysis.ipynb',
#  'Network-analysis-REMP.ipynb']

# %%
from scripts.network_analysis import retrieve_spreadsheet_records

entity_records = retrieve_spreadsheet_records(record_type='entities')
print('Number of records:' , len(entity_records))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-4e100b18a24c> in <module>
# ----> 1 from .scripts.network_analysis import retrieve_spreadsheet_records
#       2
#       3 entity_records = retrieve_spreadsheet_records(record_type='entities')
#       4 print('Number of records:' , len(entity_records))
#
# ModuleNotFoundError: No module named '__main__.scripts'; '__main__' is not a package

# %%
import json

for record in entity_records:
    print(json.dumps(record, indent=4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-55e3d65b60f6> in <module>
#       1 import json
#       2
# ----> 3 for record in entity_records:
#       4     print(json.dumps(record, indent=4))
#
# NameError: name 'entity_records' is not defined

# %%
# index each person entity with their category (academic, technocrat)
def get_entity_name(entity: dict):
    name_labels = ['Prs_surname', 'Prs_infix', 'Prs_initials']
    if entity['Prs_infix'] != '':
        return f"{entity['Prs_surname']}, {entity['Prs_infix']}, {entity['Prs_initials']}"
    else:
        return f"{entity['Prs_surname']}, {entity['Prs_initials']}"

entity_category = {get_entity_name(record): record['Prs_category'] for record in entity_records}
entity_category['Haveman, B.']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-229921e24476> in <module>
#       7         return f"{entity['Prs_surname']}, {entity['Prs_initials']}"
#       8
# ----> 9 entity_category = {get_entity_name(record): record['Prs_category'] for record in entity_records}
#      10 entity_category['Haveman, B.']
#
# NameError: name 'entity_records' is not defined

# %%
from scripts.network_analysis import retrieve_spreadsheet_records

relationship_records = retrieve_spreadsheet_records(record_type='relationships')
len(relationship_records)
# Out:
# 143

# %%
from collections import defaultdict, Counter

from scripts.network_analysis import extract_record_entities


def get_entity_category(entity: dict):
    if entity['entity_name'] in entity_category:
        return entity_category[entity['entity_name']] 
    else:
        return 'unknown'


record_entities = defaultdict(list)
entity_count = Counter()
entity_role_count = Counter()
for ri, record in enumerate(relationship_records):
    entities = extract_record_entities(record)
    record_entities[ri].append(entities)
    entity_count.update([entity['entity_name'] for entity in entities if 'entity_name' in entity])
    entity_role_count.update([entity['entity_role'] + ' ' + entity['entity_name'] for entity in entities if 'entity_name' in entity])
    for entity in entities:
        if entity['entity_type'] == 'person':
            entity['entity_type'] = get_entity_category(entity)
        print(entity)
    print(ri)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-935569f2c482> in <module>
#       1 from collections import defaultdict, Counter
#       2
# ----> 3 from scripts.network_analysis import extract_record_entities
#       4
#       5
#
# ModuleNotFoundError: No module named 'scripts'

# %%
for entity, count in entity_count.most_common():
    print(f'{entity: <30}{count: >3}')
# Out:
# Beijer, G.                    147
# REMP                           25
# RCE                             5
# Groenman, Sj.                   5
# Hofstee, E.W.                   5
# ICEM                            4
# Edding, F.                      4
# Sauvy, A.                       3
# Zeegers, G.H.L.                 3
# Isaac, J.                       3
# Hack, H.                        3
# Mol, J.J.                       3
# Radspieler, T.                  3
# Zubrzycki, J.                   3
# Richardson, A.                  3
# Hofstede, B.P.                  2
# Frijda, N.H.                    2
# Haveman, B.W.                   2
# Wentholt, R.                    2
# Gadolin, de, A.                 2
# Petersen, W.                    2
# Mill, van, A.N.                 2
# Ipsen, G.                       2
# Beld, van den, C.A.             2
# Appleyard, R.T.                 2
# Timlin, M.F.                    2
# Rosenfield, H.N.                2
# Rubin, E.                       2
# Bouscaren, A.T.                 2
# Duijker, H.C.J.                 1
# Wander, H.                      1
# Bouman, P.J.                    1
# Citroen, H.A.                   1
# Rappard, W.E.                   1
# Oudegeest, J.J.                 1
# Brink, van den , T.             1
# Salin, E.                       1
# HWvanLoon Fellowship, NL regering  1
# Institute of International Education  1
# Davis, K.                       1
# Glass, D.V.                     1
# Lannes, X.                      1
# Avila, de, F.B.                 1
# Camillo de Oliveira, A.         1
# Steigenga, W.                   1
# Verwey-Jonker, H.               1
# Brackel, P.O.M.                 1
# Klompe, M.                      1
# Verkade, W.                     1
# Paikert, G.C.                   1
# Ex, J.                          1
# Rutten, F.J.Th.                 1
# Johnston, R.                    1
# Weinstock, S. Alexander         1
# Wilder-Okladek, F.              1
# Albin, A.                       1
# Alexander, R.                   1
# Neumann, B.                     1
# Mezoff, R.                      1
# Muller, K.D.                    1
# Eidt, R.C.                      1
# WOTRO (Netherlands Foundation for the Advancement of Tropical Research)  1
# Bovenkerk, F.                   1
# Witkamp, F.Th.                  1
# Patijn, C.L.                    1
# Brepohl, W.                     1
# Lehmkuhler, M.                  1
# Visser t Hooft, W.A.            1
# Jong, de , P.                   1
# Cnossen, T.                     1
# Jain, S.K.                      1
# Stone, K.H.                     1
# Maselli, G.                     1
# Bernard, W.S.                   1
# Sassen, S.                      1
# Jorge, A.                       1
# Moncarz, R.                     1
# Mackenroth, G.                  1
# Nixon, F.W.                     1
# Mast, van der , J.              1
# Glinstra Bleeker, van, R.J.P.   1
# Sjollema, B.Ch.                 1
# MacKay, M.C.J.                  1
# Dorpema, H.                     1
# Peltier, R.                     1
# Brink, van den , T              1
# Meyers, H.G.                    1
# Godefroy, J.                    1
# Bastos de Avila, F.             1
# Weinberg, A.A.W.                1
# Mast, van der, W.               1
# Schmitz, J.P.G.                 1
# Hyrenius, H.                    1
# Mannoni, E.                     1
# Belshaw, H.                     1
# Olsson, B.                      1
# Geyl, W.F.                      1
# Borrie, W.D.                    1
# Lewis, J.N.                     1
# Sauvon, E.A.                    1
# Maris, A.                       1
# Pressat, R.                     1
# Lyon, A.V.                      1
# Herberle, R.                    1
# Starr, M.                       1
# Reid, I.D.A.                    1
# LehmKuhler, M.                  1
# Witkamp, T.                     1
# Gottmann, J.                    1
# Balhana, A.Pilatti              1
# Cidor, H.A.                     1
# Witcover, J.                    1
# Orleans, L.A.                   1
# Kraak, J.H.                     1
# Luckham, B.                     1
# Fagley, R.                      1
# Price, C.A.                     1
# Rees, E.                        1
# Paulson, B.                     1
# Heyn, H.                        1
# Putten, v.d., A.                1
# Roof, M.K.                      1
# Nixon, J.W.                     1
# Boer-Lasschuyt, de, T.          1
# Makulu, H.F.                    1
# Sumiya, M.                      1
# Fentener van Vlissingen, R.     1
# Taft, R.                        1
# Doczy, A.G.                     1
# Schreuder, O.                   1
# Bentwich, N.                    1
# Beveridge, W.H.                 1
# Neher, L.                       1
# Clemens, R.                     1
# Weinberg, A.A.                  1
# Guttman, L.                     1
# Tavuchis, N.                    1
# Schoenberg, H.W.                1
# Lattimore jr, B.G.              1

# %%
for entity, count in entity_role_count.most_common():
    print(f'{entity: <30}{count: >3}')
# Out:
# editor Beijer, G.             135
# executor_org REMP              24
# article_author Beijer, G.      12
# funder ICEM                     4
# client RCE                      4
# article_author Edding, F.       4
# article_author Hofstee, E.W.    4
# article_author Hack, H.         3
# article_author Mol, J.J.        3
# article_author Radspieler, T.   3
# article_author Zubrzycki, J.    3
# article_author Richardson, A.   3
# article_author Hofstede, B.P.   2
# preface_author Groenman, Sj.    2
# article_author Frijda, N.H.     2
# preface_author Haveman, B.W.    2
# article_author Wentholt, R.     2
# preface_author Sauvy, A.        2
# article_author Gadolin, de, A.  2
# article_author Petersen, W.     2
# article_author Groenman, Sj.    2
# article_author Isaac, J.        2
# article_author Beld, van den, C.A.  2
# article_author Appleyard, R.T.  2
# article_author Timlin, M.F.     2
# article_author Rosenfield, H.N.  2
# article_author Rubin, E.        2
# article_author Bouscaren, A.T.  2
# executor_org RCE                1
# intro_author Duijker, H.C.J.    1
# intro_author Groenman, Sj.      1
# article_author Wander, H.       1
# preface_author Bouman, P.J.     1
# article_author Citroen, H.A.    1
# preface_author Rappard, W.E.    1
# article_author Oudegeest, J.J.  1
# article_author Brink, van den , T.  1
# preface_author Salin, E.        1
# preface_author Zeegers, G.H.L.  1
# funder HWvanLoon Fellowship, NL regering  1
# client Institute of International Education  1
# preface_author Hofstee, E.W.    1
# preface_author Davis, K.        1
# preface_author Glass, D.V.      1
# article_author Lannes, X.       1
# preface_author Mill, van, A.N.  1
# article_author Avila, de, F.B.  1
# preface_author Camillo de Oliveira, A.  1
# preface_author Isaac, J.        1
# article_author Steigenga, W.    1
# preface_author Ipsen, G.        1
# article_author Verwey-Jonker, H.  1
# article_author Brackel, P.O.M.  1
# preface_author Klompe, M.       1
# intro_author Verkade, W.        1
# intro_author Zeegers, G.H.L.    1
# article_author Paikert, G.C.    1
# article_author Ex, J.           1
# preface_author Rutten, F.J.Th.  1
# article_author Johnston, R.     1
# article_author Weinstock, S. Alexander  1
# article_author Wilder-Okladek, F.  1
# article_author Albin, A.        1
# article_author Alexander, R.    1
# article_author Neumann, B.      1
# article_author Mezoff, R.       1
# article_author Muller, K.D.     1
# preface_author Eidt, R.C.       1
# funder WOTRO (Netherlands Foundation for the Advancement of Tropical Research)  1
# article_author Bovenkerk, F.    1
# article_author Witkamp, F.Th.   1
# intro_author Patijn, C.L.       1
# article_author REMP             1
# article_author Brepohl, W.      1
# article_author Lehmkuhler, M.   1
# preface_author Visser t Hooft, W.A.  1
# article_author Jong, de , P.    1
# article_author Cnossen, T.      1
# article_author Jain, S.K.       1
# article_author Stone, K.H.      1
# article_author Maselli, G.      1
# article_author Bernard, W.S.    1
# article_author Sassen, S.       1
# article_author Jorge, A.        1
# article_author Moncarz, R.      1
# article_author Sauvy, A.        1
# article_author Mackenroth, G.   1
# article_author Nixon, F.W.      1
# article_author Mast, van der , J.  1
# article_author Glinstra Bleeker, van, R.J.P.  1
# article_author Sjollema, B.Ch.  1
# article_author Zeegers, G.H.L.  1
# article_author MacKay, M.C.J.   1
# article_author Dorpema, H.      1
# article_author Peltier, R.      1
# article_author Brink, van den , T  1
# article_author Mill, van, A.N.  1
# article_author Meyers, H.G.     1
# article_author Godefroy, J.     1
# article_author Bastos de Avila, F.  1
# article_author Weinberg, A.A.W.  1
# article_author Mast, van der, W.  1
# article_author Schmitz, J.P.G.  1
# article_author Hyrenius, H.     1
# article_author Mannoni, E.      1
# article_author Belshaw, H.      1
# article_author Olsson, B.       1
# article_author Geyl, W.F.       1
# article_author Borrie, W.D.     1
# article_author Lewis, J.N.      1
# article_author Sauvon, E.A.     1
# article_author Maris, A.        1
# article_author Ipsen, G.        1
# article_author Pressat, R.      1
# article_author Lyon, A.V.       1
# article_author Herberle, R.     1
# article_author Starr, M.        1
# article_author Reid, I.D.A.     1
# article_author LehmKuhler, M.   1
# article_author Witkamp, T.      1
# article_author Gottmann, J.     1
# article_author Balhana, A.Pilatti  1
# article_author Cidor, H.A.      1
# article_author Witcover, J.     1
# article_author Orleans, L.A.    1
# article_author Kraak, J.H.      1
# article_author Luckham, B.      1
# article_author Fagley, R.       1
# article_author Price, C.A.      1
# article_author Rees, E.         1
# article_author Paulson, B.      1
# article_author Heyn, H.         1
# article_author Putten, v.d., A.  1
# article_author Roof, M.K.       1
# article_author Nixon, J.W.      1
# article_author Boer-Lasschuyt, de, T.  1
# article_author Makulu, H.F.     1
# article_author Sumiya, M.       1
# article_author Fentener van Vlissingen, R.  1
# article_author Taft, R.         1
# article_author Doczy, A.G.      1
# article_author Schreuder, O.    1
# article_author Bentwich, N.     1
# preface_author Beveridge, W.H.  1
# preface_author Neher, L.        1
# preface_author Clemens, R.      1
# article_author Weinberg, A.A.   1
# preface_author Guttman, L.      1
# article_author Tavuchis, N.     1
# article_author Schoenberg, H.W.  1
# article_author Lattimore jr, B.G.  1

# %%
from scripts.network_analysis import make_bibliographic_records

bib_records = make_bibliographic_records(relationship_records)
print(bib_records[0])
len(bib_records)
# Out:
# {'article_doi': None, 'article_page_range': None, 'article_pub_date': '1958', 'article_pub_year': 1958, 'journal': 'Studies over Nederlandse emigratie', 'volume': '1', 'issue_pub_date': '1958', 'issue_pub_year': 1958, 'issue_title': None, 'issue_page_range': None, 'publisher': 'REMP', 'issue_section': 'article', 'article_title': 'De gaande man : gronden van de emigratiebeslissing : rapport naar aanleiding van een onderzoek / verricht in opdracht van de Regeringscommissaris voor de Emigratie ', 'article_author': 'Hofstede, B.P.', 'article_author_index_name': 'Hofstede, B.P.', 'article_author_affiliation': ''}
# 169

# %%
headers = [
    'article_title', 'article_doi', 
    'article_author', 'article_author_index_name', 'article_author_affiliation', 
    'article_page_range', 'article_pub_date', 'article_pub_year', 
    'issue_section', 'journal', 'volume', 'issue', 
    'issue_title', 'issue_page_range', 'issue_pub_date', 'issue_pub_year', 
    'publisher'
]

remp_records_file = '../data/remp-records.json'
with open(remp_records_file, 'wt') as fh:
    json.dump(bib_records, fh)

# %%
from scripts.network_analysis import generate_graph, add_entities, add_record_links

graph = generate_graph()

periods = [
    {'start': 1950, 'end': 1959}, 
    {'start': 1960, 'end': 1969},
    {'start': 1970, 'end': 1979},
    {'start': 1980, 'end': 1989},
]

period = periods[0]
for record in relationship_records:
    record['year'] = int(record['year'])
for ri, record in enumerate(sorted(relationship_records, key = lambda x: x['year'])):
    record['year'] = int(record['year'])
    if record['year'] < period['start'] or record['year'] > period['end']:
        continue
    print(record['year'])
    entities = extract_record_entities(record)
    for entity in entities:
        if entity['entity_type'] == 'person':
            entity['entity_type'] = get_entity_category(entity)
    named_entities = [entity for entity in entities if 'entity_name' in entity]
    print([entity['entity_name'] for entity in named_entities])
    add_entities(graph, named_entities)
    add_record_links(graph, named_entities)
    if ri == 100:
        break

graph.number_of_nodes()
# Out:
# 1951
# ['REMP', 'Wander, H.', 'Bouman, P.J.', 'Beijer, G.']
# adding link REMP Wander, H.
# adding link REMP Bouman, P.J.
# adding link REMP Beijer, G.
# adding link Wander, H. Bouman, P.J.
# adding link Wander, H. Beijer, G.
# adding link Bouman, P.J. Beijer, G.
# 1951
# ['REMP', 'Citroen, H.A.', 'Groenman, Sj.', 'Rappard, W.E.', 'Beijer, G.']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-bb865d8b9ea4> in <module>
#      24     named_entities = [entity for entity in entities if 'entity_name' in entity]
#      25     print([entity['entity_name'] for entity in named_entities])
# ---> 26     add_entities(graph, named_entities)
#      27     add_record_links(graph, named_entities)
#      28     if ri == 100:
#
# ~/Code/Huygens/migrant_discourse/notebooks/scripts/network_analysis.py in add_entities(graph, entities)
#      21
#      22 def add_entities(graph: Graph, entities: List[Dict[str, any]]):
# ---> 23     nodes = [(entity['entity_name'], {'color': COLOR_MAP[entity['entity_type']]}) for entity in entities]
#      24     graph.add_nodes_from(nodes)
#      25
#
# ~/Code/Huygens/migrant_discourse/notebooks/scripts/network_analysis.py in <listcomp>(.0)
#      21
#      22 def add_entities(graph: Graph, entities: List[Dict[str, any]]):
# ---> 23     nodes = [(entity['entity_name'], {'color': COLOR_MAP[entity['entity_type']]}) for entity in entities]
#      24     graph.add_nodes_from(nodes)
#      25
#
# KeyError: 'diplomat'

# %%
len(graph.edges())
# Out:
# 117

# %%
graph.edges()
# Out:
# EdgeView([('REMP', 'Wander, H.'), ('REMP', 'Bouman, P.J.'), ('REMP', 'Beijer, G.'), ('REMP', 'Citroen, H.A.'), ('REMP', 'Groenman, Sj.'), ('REMP', 'Rappard, W.E.'), ('REMP', 'Edding, F.'), ('REMP', 'Salin, E.'), ('REMP', 'Oudegeest, J.J.'), ('REMP', 'Sauvy, A.'), ('REMP', 'Brink, van den , T.'), ('REMP', 'Gadolin, de, A.'), ('REMP', 'Zeegers, G.H.L.'), ('REMP', 'HWvanLoon Fellowship, NL regering'), ('REMP', 'Institute of International Education'), ('REMP', 'Petersen, W.'), ('REMP', 'Hofstee, E.W.'), ('REMP', 'Davis, K.'), ('REMP', 'Glass, D.V.'), ('REMP', 'Lannes, X.'), ('REMP', 'Mill, van, A.N.'), ('REMP', 'Avila, de, F.B.'), ('REMP', 'Camillo de Oliveira, A.'), ('REMP', 'Isaac, J.'), ('REMP', 'Steigenga, W.'), ('REMP', 'Ipsen, G.'), ('REMP', 'Verwey-Jonker, H.'), ('REMP', 'Brackel, P.O.M.'), ('REMP', 'Klompe, M.'), ('REMP', 'Verkade, W.'), ('Wander, H.', 'Bouman, P.J.'), ('Wander, H.', 'Beijer, G.'), ('Bouman, P.J.', 'Beijer, G.'), ('Beijer, G.', 'Citroen, H.A.'), ('Beijer, G.', 'Groenman, Sj.'), ('Beijer, G.', 'Rappard, W.E.'), ('Beijer, G.', 'Edding, F.'), ('Beijer, G.', 'Salin, E.'), ('Beijer, G.', 'Oudegeest, J.J.'), ('Beijer, G.', 'Sauvy, A.'), ('Beijer, G.', 'Beijer, G.'), ('Beijer, G.', 'Brink, van den , T.'), ('Beijer, G.', 'Gadolin, de, A.'), ('Beijer, G.', 'Zeegers, G.H.L.'), ('Beijer, G.', 'HWvanLoon Fellowship, NL regering'), ('Beijer, G.', 'Institute of International Education'), ('Beijer, G.', 'Petersen, W.'), ('Beijer, G.', 'Hofstee, E.W.'), ('Beijer, G.', 'Davis, K.'), ('Beijer, G.', 'Glass, D.V.'), ('Beijer, G.', 'Lannes, X.'), ('Beijer, G.', 'Mill, van, A.N.'), ('Beijer, G.', 'Bentwich, N.'), ('Beijer, G.', 'Beveridge, W.H.'), ('Beijer, G.', 'Avila, de, F.B.'), ('Beijer, G.', 'Camillo de Oliveira, A.'), ('Beijer, G.', 'Isaac, J.'), ('Beijer, G.', 'Steigenga, W.'), ('Beijer, G.', 'Ipsen, G.'), ('Beijer, G.', 'Brepohl, W.'), ('Beijer, G.', 'Lehmkuhler, M.'), ('Beijer, G.', 'Radspieler, T.'), ('Beijer, G.', 'Neher, L.'), ('Beijer, G.', 'Zubrzycki, J.'), ('Beijer, G.', 'Clemens, R.'), ('Beijer, G.', 'Verwey-Jonker, H.'), ('Beijer, G.', 'Brackel, P.O.M.'), ('Beijer, G.', 'Klompe, M.'), ('Beijer, G.', 'Verkade, W.'), ('Beijer, G.', 'Witkamp, F.Th.'), ('Beijer, G.', 'Patijn, C.L.'), ('Beijer, G.', 'Witcover, J.'), ('Citroen, H.A.', 'Groenman, Sj.'), ('Citroen, H.A.', 'Rappard, W.E.'), ('Groenman, Sj.', 'Rappard, W.E.'), ('Groenman, Sj.', 'RCE'), ('Groenman, Sj.', 'ICEM'), ('Groenman, Sj.', 'Hofstede, B.P.'), ('Edding, F.', 'Salin, E.'), ('Oudegeest, J.J.', 'Sauvy, A.'), ('Sauvy, A.', 'Brink, van den , T.'), ('Gadolin, de, A.', 'Zeegers, G.H.L.'), ('Zeegers, G.H.L.', 'Verwey-Jonker, H.'), ('Zeegers, G.H.L.', 'Brackel, P.O.M.'), ('Zeegers, G.H.L.', 'Klompe, M.'), ('Zeegers, G.H.L.', 'Verkade, W.'), ('HWvanLoon Fellowship, NL regering', 'Institute of International Education'), ('HWvanLoon Fellowship, NL regering', 'Petersen, W.'), ('HWvanLoon Fellowship, NL regering', 'Hofstee, E.W.'), ('HWvanLoon Fellowship, NL regering', 'Davis, K.'), ('Institute of International Education', 'Petersen, W.'), ('Institute of International Education', 'Hofstee, E.W.'), ('Institute of International Education', 'Davis, K.'), ('Petersen, W.', 'Hofstee, E.W.'), ('Petersen, W.', 'Davis, K.'), ('Hofstee, E.W.', 'Davis, K.'), ('Hofstee, E.W.', 'Glass, D.V.'), ('Lannes, X.', 'Mill, van, A.N.'), ('Bentwich, N.', 'Beveridge, W.H.'), ('Avila, de, F.B.', 'Camillo de Oliveira, A.'), ('Avila, de, F.B.', 'Isaac, J.'), ('Camillo de Oliveira, A.', 'Isaac, J.'), ('Steigenga, W.', 'Ipsen, G.'), ('Brepohl, W.', 'Lehmkuhler, M.'), ('Radspieler, T.', 'Neher, L.'), ('Zubrzycki, J.', 'Clemens, R.'), ('Verwey-Jonker, H.', 'Brackel, P.O.M.'), ('Verwey-Jonker, H.', 'Klompe, M.'), ('Verwey-Jonker, H.', 'Verkade, W.'), ('Brackel, P.O.M.', 'Klompe, M.'), ('Brackel, P.O.M.', 'Verkade, W.'), ('Klompe, M.', 'Verkade, W.'), ('Witkamp, F.Th.', 'Patijn, C.L.'), ('RCE', 'ICEM'), ('RCE', 'RCE'), ('RCE', 'Hofstede, B.P.'), ('ICEM', 'Hofstede, B.P.')])

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
color_map = []
for node in graph:
    color_map.append(graph.nodes[node]['color'])
nx.draw(graph, node_color=color_map, with_labels=True)
plt.show()

# %%
#nx.draw_spring(graph, with_labels=True, font_weight='bold')
pos = nx.spring_layout(graph, k=0.9)
#nx.draw_networkx_nodes(graph, pos)
#nx.draw_spectral(graph, with_labels=True, font_weight='bold')
pos
# Out:
# {'REMP': array([-0.10127724,  0.06048915]),
#  'Wander, H.': array([-0.41908396,  0.75268787]),
#  'Bouman, P.J.': array([-0.22741325,  0.80178057]),
#  'Beijer, G.': array([-0.01116272,  0.04132534]),
#  'Citroen, H.A.': array([-0.51062682, -0.35135988]),
#  'Groenman, Sj.': array([ 0.03927459, -0.46967387]),
#  'Rappard, W.E.': array([-0.66277188, -0.197472  ]),
#  'Edding, F.': array([ 0.36160805, -0.51009477]),
#  'Salin, E.': array([ 0.08947972, -0.65255735]),
#  'Oudegeest, J.J.': array([ 0.59092401, -0.32119582]),
#  'Sauvy, A.': array([ 0.47763006, -0.16072608]),
#  'Brink, van den , T.': array([0.3361151 , 0.39257799]),
#  'Gadolin, de, A.': array([-0.50826167,  0.5717385 ]),
#  'Zeegers, G.H.L.': array([-0.69697378,  0.34441062]),
#  'HWvanLoon Fellowship, NL regering': array([0.5529841 , 0.12436591]),
#  'Institute of International Education': array([0.16277223, 0.14008708]),
#  'Petersen, W.': array([0.44184538, 0.24076242]),
#  'Hofstee, E.W.': array([ 0.29162349, -0.08842132]),
#  'Davis, K.': array([ 0.55298172, -0.03075614]),
#  'Glass, D.V.': array([ 0.2268466 , -0.40519155]),
#  'Lannes, X.': array([0.16915069, 0.74026764]),
#  'Mill, van, A.N.': array([0.00244154, 0.80412696]),
#  'Bentwich, N.': array([-0.17432349, -0.93286533]),
#  'Beveridge, W.H.': array([ 0.05639545, -1.        ]),
#  'Avila, de, F.B.': array([-0.39863119, -0.28374188]),
#  'Camillo de Oliveira, A.': array([-0.27693214, -0.53963646]),
#  'Isaac, J.': array([-0.05667506, -0.3309101 ]),
#  'Steigenga, W.': array([-0.67266943, -0.36638574]),
#  'Ipsen, G.': array([-0.64852602,  0.12465163]),
#  'Brepohl, W.': array([0.78948363, 0.43673632]),
#  'Lehmkuhler, M.': array([0.98293304, 0.08467448]),
#  'Radspieler, T.': array([0.88095479, 0.32286857]),
#  'Neher, L.': array([0.68683925, 0.69526514]),
#  'Zubrzycki, J.': array([-0.23815123,  0.54976985]),
#  'Clemens, R.': array([0.42033295, 0.59850477]),
#  'Verwey-Jonker, H.': array([-0.36604183,  0.28885587]),
#  'Brackel, P.O.M.': array([-0.46264617, -0.02099882]),
#  'Klompe, M.': array([-0.5687393 ,  0.38811556]),
#  'Verkade, W.': array([-0.50908711,  0.15508851]),
#  'Witkamp, F.Th.': array([-0.73092942,  0.09087152]),
#  'Patijn, C.L.': array([-0.06822092,  0.53948462]),
#  'RCE': array([0.39912732, 0.001587  ]),
#  'ICEM': array([ 0.6594101 , -0.66160206]),
#  'Hofstede, B.P.': array([ 0.6075923 , -0.82609501]),
#  'Witcover, J.': array([-0.86302552, -0.56175946]),
#  'Hack, H.': array([-0.60657594, -0.57965027])}

# %%
fig=plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')

nx.draw_networkx_nodes(graph, pos)
nx.draw_spring(graph, with_labels=False, font_weight='bold')

# %%
    
nodes_of_largest_component  = max(nx.connected_components(graph), key = len)
largest_component = graph.subgraph(nodes_of_largest_component)
color_map = []
for node in largest_component:
    color_map.append(graph.nodes[node]['color'])

nx.draw_spring(largest_component, node_color=color_map, with_labels=True)
#nx.draw(largest_component, node_color=color_map, with_labels=True)
